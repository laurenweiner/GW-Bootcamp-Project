# %%
import sqlalchemy
from sqlalchemy import create_engine, func, inspect
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
# FOR PostgreSQL connection : 
db_string = f"postgresql://postgres:XB0j1ma!17@housingdata.cng7z9pmjc4z.us-east-1.rds.amazonaws.com:5432/postgres"
engine = create_engine(db_string)
conn = engine.connect()
inspector = inspect(engine)

# %%
#get all the data from SQL using conn 
results = conn.execute("SELECT * FROM market_pop_data")

#find the column names
column_list = []
for row in inspector.get_columns("market_pop_data"):
    column_list.append(row["name"])
    
market_pop_data= pd.DataFrame(results, columns = column_list)
print(market_pop_data.shape)
market_pop_data.head(5)
# Out:
# (470, 21)
#   state_name year_data  median_sale_price  median_list_price   homes_sold  \
# 0    Alabama      2012        141383.3333        174433.3333   263.333333
# 1    Alabama      2013        153825.0000        155558.3333  1801.166667
# 2    Alabama      2014        157191.6667        159683.3333  1850.166667
# 3    Alabama      2015        162108.3333        164833.3333  2066.166667
# 4    Alabama      2016        170041.6667        172683.3333  2283.416667
#
#    new_listings     inventory  avg_sale_to_list  sold_above_list  \
# 0    242.166667   1109.333333          0.931812         0.117615
# 1   1838.083333   8119.750000          0.959974         0.185273
# 2   1889.500000   8391.250000          0.960012         0.177185
# 3   2401.583333   9340.416667          0.963852         0.189315
# 4   2625.083333  11045.416670          0.969219         0.211927
#
#    popestimate2010  ...  popestimate2012  popestimate2013  popestimate2014  \
# 0        4785514.0  ...        4816632.0        4831586.0        4843737.0
# 1        4785514.0  ...        4816632.0        4831586.0        4843737.0
# 2        4785514.0  ...        4816632.0        4831586.0        4843737.0
# 3        4785514.0  ...        4816632.0        4831586.0        4843737.0
# 4        4785514.0  ...        4816632.0        4831586.0        4843737.0
#
#    popestimate2015  popestimate2016  popestimate2017  popestimate2018  \
# 0        4854803.0        4866824.0        4877989.0        4891628.0
# 1        4854803.0        4866824.0        4877989.0        4891628.0
# 2        4854803.0        4866824.0        4877989.0        4891628.0
# 3        4854803.0        4866824.0        4877989.0        4891628.0
# 4        4854803.0        4866824.0        4877989.0        4891628.0
#
#    popestimate2019  popestimate2020  popestimate2021
# 0        4907965.0        4921532.0        5039877.0
# 1        4907965.0        4921532.0        5039877.0
# 2        4907965.0        4921532.0        5039877.0
# 3        4907965.0        4921532.0        5039877.0
# 4        4907965.0        4921532.0        5039877.0
#
# [5 rows x 21 columns]

# %%
sns.boxplot(market_pop_data.sold_above_list)
plt.savefig("boxplot_sold_above_list.png")
# Out:
# /Users/oyukaagi/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
market_pop_data["state_name"].value_counts()
# Out:
# Alabama                 10
# Oregon                  10
# Nebraska                10
# Nevada                  10
# New Hampshire           10
# New Jersey              10
# New Mexico              10
# New York                10
# North Carolina          10
# Ohio                    10
# Oklahoma                10
# Pennsylvania            10
# Mississippi             10
# Rhode Island            10
# South Carolina          10
# Tennessee               10
# Texas                   10
# Utah                    10
# Vermont                 10
# Virginia                10
# Washington              10
# West Virginia           10
# Missouri                10
# Minnesota               10
# Alaska                  10
# Hawaii                  10
# Arizona                 10
# Arkansas                10
# California              10
# Colorado                10
# District of Columbia    10
# Connecticut             10
# Delaware                10
# Florida                 10
# Georgia                 10
# Idaho                   10
# Michigan                10
# Illinois                10
# Indiana                 10
# Iowa                    10
# Kansas                  10
# Kentucky                10
# Louisiana               10
# Maine                   10
# Maryland                10
# Massachusetts           10
# Wisconsin               10
# Name: state_name, dtype: int64

# %%
df = market_pop_data.groupby("state_name").mean()
df.head(5)
# Out:
#             median_sale_price  median_list_price    homes_sold  new_listings  \
# state_name
# Alabama          183915.00000       188797.49999   2172.750000   2341.158333
# Alaska           288405.00000       280217.50001    493.141667    636.650000
# Arizona          255819.16667       255318.33334   7920.475000   8887.741667
# Arkansas         160208.33334       165490.83334   1847.941667   2095.658333
# California       533084.16667       504915.00001  23315.050000  26865.333334
#
#                inventory  avg_sale_to_list  sold_above_list  popestimate2010  \
# state_name
# Alabama      8056.675000          0.969110         0.222344        4785514.0
# Alaska       2462.066667          0.985563         0.212525         713982.0
# Arizona     22158.108333          0.985570         0.218675        6407342.0
# Arkansas     7387.250000          0.964521         0.142751        2921998.0
# California  52670.708333          1.001858         0.384852       37319550.0
#
#             popestimate2011  popestimate2012  popestimate2013  \
# state_name
# Alabama           4799642.0        4816632.0        4831586.0
# Alaska             722349.0         730810.0         737626.0
# Arizona           6473416.0        6556344.0        6634690.0
# Arkansas          2941038.0        2952876.0        2960459.0
# California       37636311.0       37944551.0       38253768.0
#
#             popestimate2014  popestimate2015  popestimate2016  \
# state_name
# Alabama           4843737.0        4854803.0        4866824.0
# Alaska             737075.0         738430.0         742575.0
# Arizona           6732873.0        6832810.0        6944767.0
# Arkansas          2968759.0        2979732.0        2991815.0
# California       38586706.0       38904296.0       39149186.0
#
#             popestimate2017  popestimate2018  popestimate2019  \
# state_name
# Alabama           4877989.0        4891628.0        4907965.0
# Alaska             740983.0         736624.0         733603.0
# Arizona           7048088.0        7164228.0        7291843.0
# Arkansas          3003855.0        3012161.0        3020985.0
# California       39337785.0       39437463.0       39437610.0
#
#             popestimate2020  popestimate2021
# state_name
# Alabama           4921532.0        5039877.0
# Alaska             731158.0         732673.0
# Arizona           7421401.0        7276316.0
# Arkansas          3030522.0        3025891.0
# California       39368078.0       39237836.0

# %%
df.shape
# Out:
# (47, 19)

# %%
df.index.name = None
# df['popestimate2021'].sort_values().plot()
sns.histplot(data=df['popestimate2021'])
plt.savefig("popestimate2021.png")

# %%
df.loc[df.popestimate2021 == df.popestimate2021.max()]
df1 = df.drop("California")

# %%
df.loc[df.popestimate2021 == df.popestimate2021.max()]
# Out:
#             median_sale_price  median_list_price  homes_sold  new_listings  \
# California       533084.16667       504915.00001    23315.05  26865.333334
#
#                inventory  avg_sale_to_list  sold_above_list  popestimate2010  \
# California  52670.708333          1.001858         0.384852       37319550.0
#
#             popestimate2011  popestimate2012  popestimate2013  \
# California       37636311.0       37944551.0       38253768.0
#
#             popestimate2014  popestimate2015  popestimate2016  \
# California       38586706.0       38904296.0       39149186.0
#
#             popestimate2017  popestimate2018  popestimate2019  \
# California       39337785.0       39437463.0       39437610.0
#
#             popestimate2020  popestimate2021
# California       39368078.0       39237836.0

# %%
y =  np.array(df1.popestimate2021)
X = df1.drop(columns = "popestimate2021" )

# %%
from sklearn.preprocessing import StandardScaler
data_scaler = StandardScaler()
X_scaled = data_scaler.fit_transform(X)
y_scaled = data_scaler.fit_transform(y.reshape(-1, 1))

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.25, random_state = 42)

# %%
# Resample the training data with SMOTE
from imblearn.over_sampling import SMOTE
X_resampled, y_resampled = SMOTE(random_state=1, sampling_strategy='auto').fit_resample(
    X_train, y_train
)
regr = LinearRegression()
regr.fit(X_resampled, y_resampled)
# Out:
# LinearRegression()

# %%
pred = regr.predict(X_test)
pred_train = regr.predict(X_train)

# %%
from sklearn.metrics import mean_absolute_error, r2_score
print("MRE: " + str( mean_absolute_error(y_test, pred)))
print("R2 test: " + str(r2_score(y_test, pred)))
print("R2 train: " + str(r2_score(y_train, pred_train)))
print("R2 weighted: " + str(r2_score(y_test, pred, multioutput='variance_weighted')))
# Out:
# MRE: 250475.04945315156
# R2 test: 0.9970257854664779
# R2 train: 0.9999406572709352
# R2 weighted: 0.9970257854664779

# %%
regr.predict(X).round(2)
# Out:
# /Users/oyukaagi/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# array([2.78422476e+13, 3.94852457e+12, 4.05784975e+13, 1.72607529e+13,
#        3.18671596e+13, 2.02487894e+13, 5.48105570e+12, 3.72181752e+12,
#        1.16088813e+14, 5.99675089e+13, 7.55633090e+12, 1.01152513e+13,
#        7.13363423e+13, 3.77351678e+13, 1.75837760e+13, 1.64557542e+13,
#        2.54441265e+13, 2.55580261e+13, 7.52337779e+12, 3.39976254e+13,
#        3.77028606e+13, 5.56306044e+13, 3.13477162e+13, 1.67179351e+13,
#        3.48151549e+13, 1.05332518e+13, 1.75898111e+13, 7.54239734e+12,
#        5.06381320e+13, 1.21843804e+13, 1.08723170e+14, 5.85483749e+13,
#        6.57902736e+13, 2.20965126e+13, 2.28891943e+13, 7.25033126e+13,
#        5.91597015e+12, 2.89373565e+13, 3.86088888e+13, 1.57371141e+14,
#        1.76171907e+13, 3.67125510e+12, 4.78059380e+13, 4.22687032e+13,
#        1.01439864e+13, 3.29770413e+13])

# %%
#Gradient Booster

# %%
params = {
    "n_estimators": 5000,
    "max_depth": 4,
    "min_samples_split": 5,
    "learning_rate": 0.01,
    "loss": "squared_error",
}

# %%
import numpy as np
from sklearn import datasets, ensemble
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
reg = ensemble.GradientBoostingRegressor(**params)
reg.fit(X_train, y_train)

mse = mean_squared_error(y_test, reg.predict(X_test))
print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
# Out:
# The mean squared error (MSE) on test set: 8546633673323.4209

# %%
test_score = np.zeros((params["n_estimators"],), dtype=np.float64)
for i, y_pred in enumerate(reg.staged_predict(X_test)):
    test_score[i] = reg.loss_(y_test, y_pred)

fig = plt.figure(figsize=(6, 6))
plt.subplot(1, 1, 1)
plt.title("Deviance")
plt.plot(
    np.arange(params["n_estimators"]) + 1,
    reg.train_score_,
    "b-",
    label="Training Set Deviance",
)
plt.plot(
    np.arange(params["n_estimators"]) + 1, test_score, "r-", label="Test Set Deviance"
)
plt.legend(loc="upper right")
plt.xlabel("Boosting Iterations")
plt.ylabel("Deviance")
fig.tight_layout()
plt.show()

# %%
feature_importance = reg.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + 0.5
fig = plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.barh(pos, feature_importance[sorted_idx], align="center")
plt.yticks(pos, np.array(df.columns)[sorted_idx])
plt.title("Feature Importance (MDI)")

result = permutation_importance(
    reg, X_test, y_test, n_repeats=10, random_state=42, n_jobs=2
)
sorted_idx = result.importances_mean.argsort()
plt.subplot(1, 2, 2)
plt.boxplot(
    result.importances[sorted_idx].T,
    vert=False,
    labels=np.array(df.columns)[sorted_idx],
)
plt.title("Permutation Importance (test set)")
fig.tight_layout()
plt.show()

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import scale
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline

# %%
lm = LinearRegression()
scores = cross_val_score(lm, X_train, y_train, scoring='r2', cv=5)
scores
# Out:
# array([0.99928699, 0.99987073, 0.9989531 , 0.99969247, 0.99870594])

# %%
folds = KFold(n_splits = 5, shuffle = True, random_state = 100)
scores = cross_val_score(lm, X_train, y_train, scoring='r2', cv=folds)
scores
# Out:
# array([0.99858856, 0.99972936, 0.99954917, 0.99918065, 0.9996025 ])

# %%
scores = cross_val_score(lm, X_train, y_train, scoring='neg_mean_squared_error', cv=5)
scores
# Out:
# array([-6.13705051e+09, -4.54298588e+09, -9.24685218e+09, -1.12288848e+09,
#        -1.20459242e+10])

# %%
# step-1: create a cross-validation scheme
folds = KFold(n_splits = 5, shuffle = True, random_state = 100)

# step-2: specify range of hyperparameters to tune
hyper_params = [{'n_features_to_select': list(range(1, 8))}]


# step-3: perform grid search
# 3.1 specify model
lm = LinearRegression()
lm.fit(X_train, y_train)
rfe = RFE(lm)             

# 3.2 call GridSearchCV()
model_cv = GridSearchCV(estimator = rfe, 
                        param_grid = hyper_params, 
                        scoring= 'r2', 
                        cv = folds, 
                        verbose = 1,
                        return_train_score=True)      

# fit the model
model_cv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=100, shuffle=True),
#              estimator=RFE(estimator=LinearRegression()),
#              param_grid=[{'n_features_to_select': [1, 2, 3, 4, 5, 6, 7]}],
#              return_train_score=True, scoring='r2', verbose=1)

# %%
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.012780      0.004021         0.000437        0.000064
# 1       0.008031      0.000255         0.000367        0.000028
# 2       0.007588      0.000342         0.000414        0.000068
# 3       0.007038      0.000280         0.000374        0.000046
# 4       0.008265      0.001872         0.000393        0.000015
# 5       0.006290      0.000268         0.000353        0.000018
# 6       0.005485      0.000076         0.000326        0.000005
#
#   param_n_features_to_select                       params  split0_test_score  \
# 0                          1  {'n_features_to_select': 1}           0.998701
# 1                          2  {'n_features_to_select': 2}           0.999492
# 2                          3  {'n_features_to_select': 3}           0.999560
# 3                          4  {'n_features_to_select': 4}           0.999510
# 4                          5  {'n_features_to_select': 5}           0.999404
# 5                          6  {'n_features_to_select': 6}           0.999142
# 6                          7  {'n_features_to_select': 7}           0.999128
#
#    split1_test_score  split2_test_score  split3_test_score  ...  \
# 0           0.998940           0.998124           0.993586  ...
# 1           0.999754           0.999781           0.994706  ...
# 2           0.999619           0.999791           0.994812  ...
# 3           0.999608           0.999721           0.994558  ...
# 4           0.999628           0.999723           0.998066  ...
# 5           0.999604           0.999387           0.998367  ...
# 6           0.999523           0.999162           0.998311  ...
#
#    mean_test_score  std_test_score  rank_test_score  split0_train_score  \
# 0         0.997610        0.002030                7            0.999543
# 1         0.998621        0.001964                5            0.999754
# 2         0.998634        0.001915                4            0.999767
# 3         0.998554        0.002001                6            0.999772
# 4         0.999239        0.000601                1            0.999798
# 5         0.999187        0.000436                2            0.999861
# 6         0.999104        0.000422                3            0.999861
#
#    split1_train_score  split2_train_score  split3_train_score  \
# 0            0.999050            0.999163            0.997604
# 1            0.999345            0.999649            0.999432
# 2            0.999541            0.999649            0.999436
# 3            0.999541            0.999668            0.999447
# 4            0.999617            0.999668            0.999914
# 5            0.999636            0.999889            0.999919
# 6            0.999645            0.999894            0.999920
#
#    split4_train_score  mean_train_score  std_train_score
# 0            0.999057          0.998883         0.000664
# 1            0.999663          0.999568         0.000154
# 2            0.999663          0.999611         0.000113
# 3            0.999677          0.999621         0.000114
# 4            0.999677          0.999735         0.000108
# 5            0.999875          0.999836         0.000102
# 6            0.999877          0.999839         0.000099
#
# [7 rows x 21 columns]

# %%
plt.figure(figsize=(16,6))

plt.plot(cv_results["param_n_features_to_select"], cv_results["mean_test_score"])
plt.plot(cv_results["param_n_features_to_select"], cv_results["mean_train_score"])
plt.xlabel('number of features')
plt.ylabel('r-squared')
plt.title("Optimal Number of Features")
plt.legend(['test score', 'train score'], loc='upper left')

# %%
# final model
n_features_optimal = 5

lm = LinearRegression()
lm.fit(X_train, y_train)

rfe = RFE(lm, n_features_to_select=n_features_optimal)             
rfe = rfe.fit(X_train, y_train)

# predict prices of X_test
y_pred = lm.predict(X_test)
r2 = sklearn.metrics.r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.9970257854664779

# %%
df1["popestimate2022"] = regr.predict(X_scaled).round(2)
df1["% inc_pop"] = ( ( df1["popestimate2022"] - df1["popestimate2021"] ) / df1["popestimate2021"] ) * 100

# %%
# States with highest predicted increase in population in 2022
df2 = df1.sort_values( by = ["% inc_pop"], ascending = False)
df2
# Out:
#                       median_sale_price  median_list_price    homes_sold  \
# New Hampshire              265613.33332       260323.33333   1350.616667
# Rhode Island               265173.33333       273919.99999    855.550000
# Nevada                     263596.66666       260008.33333   3632.333333
# Illinois                   221297.50001       220130.00000   7302.708333
# New Mexico                 374445.83334       370192.50000    173.508333
# Connecticut                268022.49999       257849.99999   2408.975000
# Missouri                   168252.50001       166909.99999   4021.008333
# West Virginia              192243.33332       193578.33335    297.050000
# Pennsylvania               219765.83333       207168.33334   6350.900000
# Wisconsin                  173907.49999       177841.66667   4055.966666
# Alaska                     288405.00000       280217.50001    493.141667
# Kentucky                   173725.00001       174328.33334   2571.708333
# Colorado                   381653.33333       357649.16666   5049.900000
# Arkansas                   160208.33334       165490.83334   1847.941667
# North Carolina             235610.00000       236900.83334   6832.091667
# Mississippi                165460.00000       173054.16667   1085.191667
# Washington                 386620.00000       370166.66666   7399.958333
# Virginia                   361653.33334       316584.16666   5086.466667
# Oregon                     321075.83334       320921.66668   4267.616667
# Ohio                       152100.83335       150452.49998   9482.016666
# Arizona                    255819.16667       255318.33334   7920.475000
# New York                   286790.00000       298480.83333   6974.750000
# Alabama                    183915.00000       188797.49999   2172.750000
# Minnesota                  235153.33333       230010.00000   5177.183333
# Massachusetts              410641.66665       401450.83333   3907.541667
# Maryland                   348680.83333       304754.16667   3967.150000
# Georgia                    221064.16666       222010.00000   9114.725001
# Tennessee                  217078.33334       223935.00001   5490.658333
# Michigan                   158980.83334       159933.33334   8777.150000
# Hawaii                     612344.99999       532436.66667    602.833333
# Oklahoma                   163849.99999       165145.00001   3280.508333
# South Carolina             232801.66668       229982.50000   3598.300000
# Indiana                    172925.00000       174473.33335   3106.416667
# Louisiana                  204485.00001       210112.50001   1888.483333
# Iowa                       188682.50001       185931.66667   1005.208333
# Kansas                     238449.16665       233579.99999   1129.100000
# District of Columbia       781050.83338       542969.99999    111.975000
# New Jersey                 305103.33333       299906.66667   5956.675000
# Nebraska                   181660.83333       184495.83333   1352.750000
# Idaho                      246784.16667       261498.33332   1906.983333
# Maine                      191874.66667       223126.66667    980.653333
# Utah                       315550.83334       303381.66666   2767.533333
# Texas                      232000.83333       240830.83334  21126.075000
# Delaware                   248491.66665       226500.00001    529.283333
# Florida                    244324.16666       232801.66668  20843.816667
# Vermont                    231560.00000       239617.50000    534.916667
#
#                       new_listings     inventory  avg_sale_to_list  \
# New Hampshire          1575.408333   5772.033334          0.977345
# Rhode Island           1066.550000   3297.541667          0.973354
# Nevada                 4145.333333  12130.858333          0.989886
# Illinois               9270.041667  27688.141668          0.969473
# New Mexico              186.841667    751.150000          0.972281
# Connecticut            3110.691667  12312.883333          0.970433
# Missouri               4640.133333   7796.733334          0.970782
# West Virginia           399.541667   1476.541667          0.969260
# Pennsylvania           7517.316667  22701.058335          0.969472
# Wisconsin              4571.633333  16377.716666          0.966693
# Alaska                  636.650000   2462.066667          0.985563
# Kentucky               3095.325000   9255.383333          0.968954
# Colorado               6205.641667  10813.433333          0.996409
# Arkansas               2095.658333   7387.250000          0.964521
# North Carolina         7674.425000  24821.158332          0.976787
# Mississippi            1177.533333   5419.383333          0.964091
# Washington             8274.591667  15814.941666          1.001278
# Virginia               6098.416667  15202.633334          0.986879
# Oregon                 4541.900000  10916.141667          0.992791
# Ohio                  11450.966666  37363.558334          0.967838
# Arizona                8887.741667  22158.108333          0.985570
# New York               8988.641667  33632.341666          0.970050
# Alabama                2341.158333   8056.675000          0.969110
# Minnesota              5910.050000  15997.341666          0.985247
# Massachusetts          4739.208333  12926.441667          0.987903
# Maryland               4906.275000  13807.483334          0.984479
# Georgia               10697.491666  32083.008332          0.976527
# Tennessee              6119.841667  19035.625000          0.974203
# Michigan              10329.091666  27592.574998          0.973567
# Hawaii                  670.775000   2975.083333          0.975991
# Oklahoma               3275.858333   9096.441666          0.974417
# South Carolina         4179.250000  15893.075000          0.974371
# Indiana                3541.033333   9700.466667          0.970952
# Louisiana              2020.775000   7767.683333          0.970516
# Iowa                   1161.250000   3904.508333          0.977128
# Kansas                 1289.700000    191.641667          0.949742
# District of Columbia    134.591667    271.566667          0.996086
# New Jersey             7252.691667  26017.841665          0.969400
# Nebraska               1495.858333   2820.216667          0.985904
# Idaho                  1956.675000   6426.825000          0.988463
# Maine                  1098.847222   3757.641667          0.955031
# Utah                   3253.283333   9052.766667          0.992845
# Texas                 25407.550000  62733.808333          0.981071
# Delaware                635.891667   1890.508333          0.979714
# Florida               23655.758333  74417.158333          0.970100
# Vermont                 684.350000   3696.391667          0.953940
#
#                       sold_above_list  popestimate2010  popestimate2011  \
# New Hampshire                0.315991        1316807.0        1320444.0
# Rhode Island                 0.253153        1053994.0        1053829.0
# Nevada                       0.279590        2702483.0        2713114.0
# Illinois                     0.205548       12840545.0       12867783.0
# New Mexico                   0.013134        2064614.0        2080707.0
# Connecticut                  0.223851        3579173.0        3588632.0
# Missouri                     0.210493        5996089.0        6011182.0
# West Virginia                0.183816        1854265.0        1856606.0
# Pennsylvania                 0.188383       12711406.0       12747052.0
# Wisconsin                    0.227099        5690538.0        5705840.0
# Alaska                       0.212525         713982.0         722349.0
# Kentucky                     0.168480        4348464.0        4370817.0
# Colorado                     0.329904        5047539.0        5121900.0
# Arkansas                     0.142751        2921998.0        2941038.0
# North Carolina               0.237541        9574586.0        9658913.0
# Mississippi                  0.139640        2970615.0        2979147.0
# Washington                   0.365018        6743009.0        6827479.0
# Virginia                     0.255373        8024004.0        8102437.0
# Oregon                       0.322407        3837614.0        3872672.0
# Ohio                         0.205799       11539449.0       11545735.0
# Arizona                      0.218675        6407342.0        6473416.0
# New York                     0.241169       19399956.0       19499921.0
# Alabama                      0.222344        4785514.0        4799642.0
# Minnesota                    0.301695        5310934.0        5346620.0
# Massachusetts                0.321685        6566440.0        6614218.0
# Maryland                     0.245536        5788784.0        5840241.0
# Georgia                      0.223515        9712209.0        9803630.0
# Tennessee                    0.207343        6355518.0        6400298.0
# Michigan                     0.255622        9877597.0        9883053.0
# Hawaii                       0.214261        1364004.0        1379562.0
# Oklahoma                     0.219452        3760014.0        3788824.0
# South Carolina               0.170693        4635846.0        4672655.0
# Indiana                      0.163627        6490555.0        6517250.0
# Louisiana                    0.146685        4544635.0        4576244.0
# Iowa                         0.223582        3050819.0        3066772.0
# Kansas                       0.159997        2858266.0        2869677.0
# District of Columbia         0.342673         605282.0         620290.0
# New Jersey                   0.212277        8799451.0        8828552.0
# Nebraska                     0.293427        1829591.0        1840914.0
# Idaho                        0.243092        1570819.0        1584272.0
# Maine                        0.185779        1327651.0        1328473.0
# Utah                         0.315497        2775413.0        2814797.0
# Texas                        0.215545       25241897.0       25645504.0
# Delaware                     0.206569         899647.0         907590.0
# Florida                      0.172334       18846143.0       19055607.0
# Vermont                      0.148168         625886.0         627197.0
#
#                       popestimate2012  ...  popestimate2014  popestimate2015  \
# New Hampshire               1324677.0  ...        1334257.0        1337480.0
# Rhode Island                1054893.0  ...        1056511.0        1056886.0
# Nevada                      2744670.0  ...        2818935.0        2868531.0
# Illinois                   12883029.0  ...       12885092.0       12859585.0
# New Mexico                  2087715.0  ...        2090236.0        2090071.0
# Connecticut                 3595211.0  ...        3595697.0        3588561.0
# Missouri                    6026027.0  ...        6059130.0        6075411.0
# West Virginia               1857446.0  ...        1850569.0        1843332.0
# Pennsylvania               12769123.0  ...       12792392.0       12789838.0
# Wisconsin                   5720825.0  ...        5753199.0        5762927.0
# Alaska                       730810.0  ...         737075.0         738430.0
# Kentucky                    4387865.0  ...        4416992.0        4429126.0
# Colorado                    5193660.0  ...        5352637.0        5454328.0
# Arkansas                    2952876.0  ...        2968759.0        2979732.0
# North Carolina              9751810.0  ...        9937295.0       10037218.0
# Mississippi                 2984599.0  ...        2991892.0        2990231.0
# Washington                  6898599.0  ...        7057531.0        7167287.0
# Virginia                    8187456.0  ...        8315430.0        8367303.0
# Oregon                      3900102.0  ...        3965447.0        4018542.0
# Ohio                       11550971.0  ...       11606573.0       11622315.0
# Arizona                     6556344.0  ...        6732873.0        6832810.0
# New York                   19574362.0  ...       19653431.0       19657321.0
# Alabama                     4816632.0  ...        4843737.0        4854803.0
# Minnesota                   5377500.0  ...        5452665.0        5484002.0
# Massachusetts               6664269.0  ...        6764864.0        6797484.0
# Maryland                    5888375.0  ...        5960064.0        5988528.0
# Georgia                     9903580.0  ...       10071204.0       10183353.0
# Tennessee                   6455752.0  ...        6544617.0        6595354.0
# Michigan                    9898289.0  ...        9932033.0        9934483.0
# Hawaii                      1395199.0  ...        1415335.0        1422999.0
# Oklahoma                    3819320.0  ...        3879187.0        3910518.0
# South Carolina              4719027.0  ...        4826858.0        4896006.0
# Indiana                     6538989.0  ...        6596019.0        6611442.0
# Louisiana                   4602067.0  ...        4645938.0        4666998.0
# Iowa                        3076844.0  ...        3110643.0        3122541.0
# Kansas                      2886024.0  ...        2901861.0        2910717.0
# District of Columbia         635737.0  ...         663603.0         677014.0
# New Jersey                  8845671.0  ...        8867277.0        8870312.0
# Nebraska                    1853691.0  ...        1879955.0        1892059.0
# Idaho                       1595910.0  ...        1632248.0        1652495.0
# Maine                       1328094.0  ...        1331217.0        1329098.0
# Utah                        2854146.0  ...        2938327.0        2983626.0
# Texas                      26084120.0  ...       26963092.0       27468531.0
# Delaware                     915518.0  ...         933131.0         942065.0
# Florida                    19302016.0  ...       19853880.0       20219111.0
# Vermont                      626361.0  ...         625693.0         625810.0
#
#                       popestimate2016  popestimate2017  popestimate2018  \
# New Hampshire               1343694.0        1350395.0        1355064.0
# Rhode Island                1057816.0        1056554.0        1059338.0
# Nevada                      2919555.0        2972097.0        3030725.0
# Illinois                   12821709.0       12779893.0       12724685.0
# New Mexico                  2092555.0        2092844.0        2093754.0
# Connecticut                 3579830.0        3575324.0        3574561.0
# Missouri                    6091384.0        6111382.0        6125986.0
# West Virginia               1832435.0        1818683.0        1805953.0
# Pennsylvania               12788468.0       12794679.0       12809107.0
# Wisconsin                   5775170.0        5793147.0        5809319.0
# Alaska                       742575.0         740983.0         736624.0
# Kentucky                    4440306.0        4455590.0        4464273.0
# Colorado                    5543844.0        5617421.0        5697155.0
# Arkansas                    2991815.0        3003855.0        3012161.0
# North Carolina             10161802.0       10275758.0       10391358.0
# Mississippi                 2990595.0        2990674.0        2982879.0
# Washington                  7299961.0        7427951.0        7526793.0
# Virginia                    8417651.0        8471011.0        8510920.0
# Oregon                      4093271.0        4147294.0        4183538.0
# Ohio                       11640060.0       11665706.0       11680892.0
# Arizona                     6944767.0        7048088.0        7164228.0
# New York                   19636391.0       19593849.0       19544098.0
# Alabama                     4866824.0        4877989.0        4891628.0
# Minnesota                   5525360.0        5569283.0        5608762.0
# Massachusetts               6827280.0        6863560.0        6885720.0
# Maryland                    6007014.0        6028186.0        6042153.0
# Georgia                    10308442.0       10417031.0       10519389.0
# Tennessee                   6651277.0        6714748.0        6778180.0
# Michigan                    9954117.0        9976752.0        9987286.0
# Hawaii                      1428885.0        1425763.0        1423102.0
# Oklahoma                    3928143.0        3933602.0        3943488.0
# South Carolina              4963031.0        5027102.0        5091702.0
# Indiana                     6637898.0        6662068.0        6698481.0
# Louisiana                   4681346.0        4673673.0        4664450.0
# Iowa                        3133210.0        3143734.0        3149900.0
# Kansas                      2912977.0        2910892.0        2912748.0
# District of Columbia         687576.0         697079.0         704147.0
# New Jersey                  8873584.0        8888147.0        8891730.0
# Nebraska                    1906483.0        1916998.0        1925512.0
# Idaho                       1684036.0        1719745.0        1752074.0
# Maine                       1332348.0        1335743.0        1340123.0
# Utah                        3044241.0        3103540.0        3155153.0
# Texas                      27914064.0       28291024.0       28624564.0
# Delaware                     949989.0         957942.0         966985.0
# Florida                    20627237.0       20977089.0       21254926.0
# Vermont                      624366.0         625132.0         624802.0
#
#                       popestimate2019  popestimate2020  popestimate2021  \
# New Hampshire               1360783.0        1366275.0        1388992.0
# Rhode Island                1058158.0        1057125.0        1095610.0
# Nevada                      3090771.0        3138259.0        3143991.0
# Illinois                   12667017.0       12587530.0       12671469.0
# New Mexico                  2099634.0        2106319.0        2115877.0
# Connecticut                 3566022.0        3557006.0        3605597.0
# Missouri                    6140475.0        6151548.0        6168187.0
# West Virginia               1795263.0        1784787.0        1782959.0
# Pennsylvania               12798883.0       12783254.0       12964056.0
# Wisconsin                   5824581.0        5832655.0        5895908.0
# Alaska                       733603.0         731158.0         732673.0
# Kentucky                    4472345.0        4477251.0        4509394.0
# Colorado                    5758486.0        5807719.0        5812069.0
# Arkansas                    3020985.0        3030522.0        3025891.0
# North Carolina             10501384.0       10600823.0       10551162.0
# Mississippi                 2978227.0        2966786.0        2949965.0
# Washington                  7614024.0        7693612.0        7738692.0
# Virginia                    8556642.0        8590563.0        8642274.0
# Oregon                      4216116.0        4241507.0        4246155.0
# Ohio                       11696507.0       11693217.0       11780017.0
# Arizona                     7291843.0        7421401.0        7276316.0
# New York                   19463131.0       19336776.0       19835913.0
# Alabama                     4907965.0        4921532.0        5039877.0
# Minnesota                   5640053.0        5657342.0        5707390.0
# Massachusetts               6894883.0        6893574.0        6984723.0
# Maryland                    6054954.0        6055802.0        6165129.0
# Georgia                    10628020.0       10710017.0       10799566.0
# Tennessee                   6830325.0        6886834.0        6975218.0
# Michigan                    9984795.0        9966555.0       10050811.0
# Hawaii                      1415615.0        1407006.0        1441553.0
# Oklahoma                    3960676.0        3980783.0        3986639.0
# South Carolina              5157702.0        5218040.0        5190705.0
# Indiana                     6731010.0        6754953.0        6805985.0
# Louisiana                   4658285.0        4645318.0        4624047.0
# Iowa                        3159596.0        3163561.0        3193079.0
# Kansas                      2912635.0        2913805.0        2934582.0
# District of Columbia         708253.0         712816.0         670050.0
# New Jersey                  8891258.0        8882371.0        9267130.0
# Nebraska                    1932571.0        1937552.0        1963692.0
# Idaho                       1789060.0        1826913.0        1900923.0
# Maine                       1345770.0        1350141.0        1372247.0
# Utah                        3203383.0        3249879.0        3337975.0
# Texas                      28986794.0       29360759.0       29527941.0
# Delaware                     976668.0         986809.0        1003384.0
# Florida                    21492056.0       21733312.0       21781128.0
# Vermont                      624046.0         623347.0         645570.0
#
#                       popestimate2022  % inc_pop
# New Hampshire              1435239.08   3.329543
# Rhode Island               1120116.89   2.236826
# Nevada                     3206920.62   2.001584
# Illinois                  12916751.53   1.935707
# New Mexico                 2151070.29   1.663296
# Connecticut                3663010.43   1.592342
# Missouri                   6251991.28   1.358653
# West Virginia              1805291.00   1.252525
# Pennsylvania              13114000.73   1.156619
# Wisconsin                  5946556.85   0.859051
# Alaska                      738571.44   0.805058
# Kentucky                   4537247.74   0.617683
# Colorado                   5835061.77   0.395604
# Arkansas                   3037078.80   0.369736
# North Carolina            10586885.34   0.338573
# Mississippi                2959424.21   0.320655
# Washington                 7763440.43   0.319801
# Virginia                   8668136.31   0.299254
# Oregon                     4257748.25   0.273029
# Ohio                      11811778.65   0.269623
# Arizona                    7284205.46   0.108427
# New York                  19843354.11   0.037513
# Alabama                    5041528.78   0.032774
# Minnesota                  5705312.95  -0.036392
# Massachusetts              6980001.28  -0.067601
# Maryland                   6156534.70  -0.139402
# Georgia                   10783076.41  -0.152688
# Tennessee                  6962964.88  -0.175666
# Michigan                  10025448.05  -0.252347
# Hawaii                     1437608.69  -0.273615
# Oklahoma                   3975100.51  -0.289429
# South Carolina             5171020.48  -0.379226
# Indiana                    6773525.27  -0.476929
# Louisiana                  4597993.52  -0.563435
# Iowa                       3173966.88  -0.598548
# Kansas                     2914614.45  -0.680422
# District of Columbia        665210.29  -0.722291
# New Jersey                 9187188.19  -0.862638
# Nebraska                   1945526.28  -0.925080
# Idaho                      1882615.20  -0.963101
# Maine                      1346917.09  -1.845871
# Utah                       3264760.93  -2.193368
# Texas                     28252115.16  -4.320741
# Delaware                    957026.70  -4.620096
# Florida                   20757744.65  -4.698486
# Vermont                     602075.34  -6.737404
#
# [46 rows x 21 columns]

# %%
df4 = df2.head(10)
df4.plot.scatter(y="% inc_pop", x="index", alpha=0.5, figsize = (15, 5))
plt.savefig("population_%_increase_2022.png")

# %%
df2["% inc_pop"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Try this in all the regions

# %%
# Dropped the highest populated regions
region_df = market_pop_data.loc[market_pop_data.state_name != "California"]
region_df
# Out:
#     state_name year_data  median_sale_price  median_list_price   homes_sold  \
# 0      Alabama      2012        141383.3333        174433.3333   263.333333
# 1      Alabama      2013        153825.0000        155558.3333  1801.166667
# 2      Alabama      2014        157191.6667        159683.3333  1850.166667
# 3      Alabama      2015        162108.3333        164833.3333  2066.166667
# 4      Alabama      2016        170041.6667        172683.3333  2283.416667
# ..         ...       ...                ...                ...          ...
# 465  Wisconsin      2017        181458.3333        182500.0000  5536.833333
# 466  Wisconsin      2018        193600.0000        195033.3333  5435.000000
# 467  Wisconsin      2019        206500.0000        205933.3333  5408.333333
# 468  Wisconsin      2020        226383.3333        222491.6667  5825.083333
# 469  Wisconsin      2021        250691.6667        239233.3333  5851.083333
#
#      new_listings     inventory  avg_sale_to_list  sold_above_list  \
# 0      242.166667   1109.333333          0.931812         0.117615
# 1     1838.083333   8119.750000          0.959974         0.185273
# 2     1889.500000   8391.250000          0.960012         0.177185
# 3     2401.583333   9340.416667          0.963852         0.189315
# 4     2625.083333  11045.416670          0.969219         0.211927
# ..            ...           ...               ...              ...
# 465   6195.416667  21632.416670          0.972616         0.224510
# 466   6249.666667  18921.916670          0.979262         0.280201
# 467   6117.166667  18498.000000          0.981036         0.290205
# 468   5894.666667  15016.083330          0.990048         0.361813
# 469   6030.666667  11988.333330          1.011113         0.506926
#
#      popestimate2010  ...  popestimate2012  popestimate2013  popestimate2014  \
# 0          4785514.0  ...        4816632.0        4831586.0        4843737.0
# 1          4785514.0  ...        4816632.0        4831586.0        4843737.0
# 2          4785514.0  ...        4816632.0        4831586.0        4843737.0
# 3          4785514.0  ...        4816632.0        4831586.0        4843737.0
# 4          4785514.0  ...        4816632.0        4831586.0        4843737.0
# ..               ...  ...              ...              ...              ...
# 465        5690538.0  ...        5720825.0        5738012.0        5753199.0
# 466        5690538.0  ...        5720825.0        5738012.0        5753199.0
# 467        5690538.0  ...        5720825.0        5738012.0        5753199.0
# 468        5690538.0  ...        5720825.0        5738012.0        5753199.0
# 469        5690538.0  ...        5720825.0        5738012.0        5753199.0
#
#      popestimate2015  popestimate2016  popestimate2017  popestimate2018  \
# 0          4854803.0        4866824.0        4877989.0        4891628.0
# 1          4854803.0        4866824.0        4877989.0        4891628.0
# 2          4854803.0        4866824.0        4877989.0        4891628.0
# 3          4854803.0        4866824.0        4877989.0        4891628.0
# 4          4854803.0        4866824.0        4877989.0        4891628.0
# ..               ...              ...              ...              ...
# 465        5762927.0        5775170.0        5793147.0        5809319.0
# 466        5762927.0        5775170.0        5793147.0        5809319.0
# 467        5762927.0        5775170.0        5793147.0        5809319.0
# 468        5762927.0        5775170.0        5793147.0        5809319.0
# 469        5762927.0        5775170.0        5793147.0        5809319.0
#
#      popestimate2019  popestimate2020  popestimate2021
# 0          4907965.0        4921532.0        5039877.0
# 1          4907965.0        4921532.0        5039877.0
# 2          4907965.0        4921532.0        5039877.0
# 3          4907965.0        4921532.0        5039877.0
# 4          4907965.0        4921532.0        5039877.0
# ..               ...              ...              ...
# 465        5824581.0        5832655.0        5895908.0
# 466        5824581.0        5832655.0        5895908.0
# 467        5824581.0        5832655.0        5895908.0
# 468        5824581.0        5832655.0        5895908.0
# 469        5824581.0        5832655.0        5895908.0
#
# [460 rows x 21 columns]

# %%
region_df = region_df.drop(columns = ["state_name", "year_data"], axis = 1)
region_df
# Out:
#      median_sale_price  median_list_price   homes_sold  new_listings  \
# 0          141383.3333        174433.3333   263.333333    242.166667
# 1          153825.0000        155558.3333  1801.166667   1838.083333
# 2          157191.6667        159683.3333  1850.166667   1889.500000
# 3          162108.3333        164833.3333  2066.166667   2401.583333
# 4          170041.6667        172683.3333  2283.416667   2625.083333
# ..                 ...                ...          ...           ...
# 465        181458.3333        182500.0000  5536.833333   6195.416667
# 466        193600.0000        195033.3333  5435.000000   6249.666667
# 467        206500.0000        205933.3333  5408.333333   6117.166667
# 468        226383.3333        222491.6667  5825.083333   5894.666667
# 469        250691.6667        239233.3333  5851.083333   6030.666667
#
#         inventory  avg_sale_to_list  sold_above_list  popestimate2010  \
# 0     1109.333333          0.931812         0.117615        4785514.0
# 1     8119.750000          0.959974         0.185273        4785514.0
# 2     8391.250000          0.960012         0.177185        4785514.0
# 3     9340.416667          0.963852         0.189315        4785514.0
# 4    11045.416670          0.969219         0.211927        4785514.0
# ..            ...               ...              ...              ...
# 465  21632.416670          0.972616         0.224510        5690538.0
# 466  18921.916670          0.979262         0.280201        5690538.0
# 467  18498.000000          0.981036         0.290205        5690538.0
# 468  15016.083330          0.990048         0.361813        5690538.0
# 469  11988.333330          1.011113         0.506926        5690538.0
#
#      popestimate2011  popestimate2012  popestimate2013  popestimate2014  \
# 0          4799642.0        4816632.0        4831586.0        4843737.0
# 1          4799642.0        4816632.0        4831586.0        4843737.0
# 2          4799642.0        4816632.0        4831586.0        4843737.0
# 3          4799642.0        4816632.0        4831586.0        4843737.0
# 4          4799642.0        4816632.0        4831586.0        4843737.0
# ..               ...              ...              ...              ...
# 465        5705840.0        5720825.0        5738012.0        5753199.0
# 466        5705840.0        5720825.0        5738012.0        5753199.0
# 467        5705840.0        5720825.0        5738012.0        5753199.0
# 468        5705840.0        5720825.0        5738012.0        5753199.0
# 469        5705840.0        5720825.0        5738012.0        5753199.0
#
#      popestimate2015  popestimate2016  popestimate2017  popestimate2018  \
# 0          4854803.0        4866824.0        4877989.0        4891628.0
# 1          4854803.0        4866824.0        4877989.0        4891628.0
# 2          4854803.0        4866824.0        4877989.0        4891628.0
# 3          4854803.0        4866824.0        4877989.0        4891628.0
# 4          4854803.0        4866824.0        4877989.0        4891628.0
# ..               ...              ...              ...              ...
# 465        5762927.0        5775170.0        5793147.0        5809319.0
# 466        5762927.0        5775170.0        5793147.0        5809319.0
# 467        5762927.0        5775170.0        5793147.0        5809319.0
# 468        5762927.0        5775170.0        5793147.0        5809319.0
# 469        5762927.0        5775170.0        5793147.0        5809319.0
#
#      popestimate2019  popestimate2020  popestimate2021
# 0          4907965.0        4921532.0        5039877.0
# 1          4907965.0        4921532.0        5039877.0
# 2          4907965.0        4921532.0        5039877.0
# 3          4907965.0        4921532.0        5039877.0
# 4          4907965.0        4921532.0        5039877.0
# ..               ...              ...              ...
# 465        5824581.0        5832655.0        5895908.0
# 466        5824581.0        5832655.0        5895908.0
# 467        5824581.0        5832655.0        5895908.0
# 468        5824581.0        5832655.0        5895908.0
# 469        5824581.0        5832655.0        5895908.0
#
# [460 rows x 19 columns]

# %%
y =  np.array(region_df.popestimate2021)
X = region_df.drop(columns = "popestimate2021" )

# %%
data_scaler = StandardScaler()
X_scaled = data_scaler.fit_transform(X)

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.25, random_state = 42)

# %%
regr = LinearRegression()
regr.fit(X_train, y_train)
pred = regr.predict(X_test)
pred_train = regr.predict(X_train)

# %%
from sklearn.metrics import mean_absolute_error, r2_score
print("MRE: " + str( mean_absolute_error(y_test, pred)))
print("R2 train: " + str(r2_score(y_train, pred_train)))
print("R2 test: " + str(r2_score(y_test, pred)))
print("R2 weighted: " + str(r2_score(y_test, pred, multioutput='variance_weighted')))
# Out:
# MRE: 39690.704472319805
# R2 train: 0.999920463821482
# R2 test: 0.9999164502988204
# R2 weighted: 0.9999164502988204

# %%
regr.predict(X)
# Out:
# /Users/oyukaagi/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# array([2.82535122e+13, 2.82516878e+13, 2.82517791e+13, 2.82518344e+13,
#        2.82519722e+13, 2.82520642e+13, 2.82521763e+13, 2.82521358e+13,
#        2.82519314e+13, 2.82518095e+13, 4.08815766e+12, 4.08826532e+12,
#        4.08854266e+12, 4.08903743e+12, 4.08885080e+12, 4.08879057e+12,
#        4.08881942e+12, 4.08912358e+12, 4.08926099e+12, 4.08890252e+12,
#        4.18948516e+13, 4.18951486e+13, 4.18957308e+13, 4.18956480e+13,
#        4.18956177e+13, 4.18954729e+13, 4.18954454e+13, 4.18954319e+13,
#        4.18950679e+13, 4.18950050e+13, 1.76418668e+13, 1.76418795e+13,
#        1.76421482e+13, 1.76420587e+13, 1.76421321e+13, 1.76421304e+13,
#        1.76422206e+13, 1.76421675e+13, 1.76423080e+13, 1.76424811e+13,
#        3.33951904e+13, 3.33949328e+13, 3.33952459e+13, 3.33949154e+13,
#        3.33950058e+13, 3.33944508e+13, 3.33934969e+13, 3.33938697e+13,
#        3.33930406e+13, 3.33919886e+13, 4.11720102e+12, 4.11648370e+12,
#        4.11853559e+12, 4.11839006e+12, 4.11994572e+12, 4.11915792e+12,
#        4.11670133e+12, 4.11783860e+12, 4.11540600e+12, 4.10563369e+12,
#        2.07486772e+13, 2.07487597e+13, 2.07489653e+13, 2.07488980e+13,
#        2.07488836e+13, 2.07490240e+13, 2.07491010e+13, 2.07495480e+13,
#        2.07488452e+13, 2.07461948e+13, 5.65996228e+12, 5.66023498e+12,
#        5.66015786e+12, 5.65985290e+12, 5.65980535e+12, 5.65986415e+12,
#        5.66010675e+12, 5.65980598e+12, 5.65996163e+12, 5.65923510e+12,
#        1.23922922e+14, 1.23922512e+14, 1.23923108e+14, 1.23923367e+14,
#        1.23923659e+14, 1.23923202e+14, 1.23923083e+14, 1.23923377e+14,
#        1.23922417e+14, 1.23920449e+14, 6.15116043e+13, 6.15111996e+13,
#        6.15110533e+13, 6.15114449e+13, 6.15117104e+13, 6.15120446e+13,
#        6.15118628e+13, 6.15120480e+13, 6.15115266e+13, 6.15106294e+13,
#        8.01791853e+12, 8.01875829e+12, 8.01798001e+12, 8.01870324e+12,
#        8.01930159e+12, 8.01897987e+12, 8.01822130e+12, 8.01827158e+12,
#        8.01739144e+12, 8.01397363e+12, 1.03750977e+13, 1.03749808e+13,
#        1.03753921e+13, 1.03753004e+13, 1.03753683e+13, 1.03757557e+13,
#        1.03758798e+13, 1.03759125e+13, 1.03763474e+13, 1.03773402e+13,
#        7.30611394e+13, 7.30614545e+13, 7.30622431e+13, 7.30623558e+13,
#        7.30621074e+13, 7.30618492e+13, 7.30617489e+13, 7.30618602e+13,
#        7.30613008e+13, 7.30596446e+13, 3.85690426e+13, 3.85692399e+13,
#        3.85690862e+13, 3.85689605e+13, 3.85691750e+13, 3.85691406e+13,
#        3.85690456e+13, 3.85691429e+13, 3.85689106e+13, 3.85686619e+13,
#        1.82516180e+13, 1.82512722e+13, 1.82514350e+13, 1.82516349e+13,
#        1.82518317e+13, 1.82519035e+13, 1.82518559e+13, 1.82517592e+13,
#        1.82522258e+13, 1.82516511e+13, 1.68034820e+13, 1.68033011e+13,
#        1.68038241e+13, 1.68038035e+13, 1.68039397e+13, 1.68039920e+13,
#        1.68041481e+13, 1.68042381e+13, 1.68042748e+13, 1.68036233e+13,
#        2.59766245e+13, 2.59765114e+13, 2.59768839e+13, 2.59766382e+13,
#        2.59765427e+13, 2.59767059e+13, 2.59767102e+13, 2.59767069e+13,
#        2.59766649e+13, 2.59763462e+13, 2.66000170e+13, 2.66002184e+13,
#        2.66005652e+13, 2.66006639e+13, 2.66007002e+13, 2.66008225e+13,
#        2.66007161e+13, 2.66005804e+13, 2.66006928e+13, 2.66003743e+13,
#        7.70697254e+12, 7.71407417e+12, 7.71182241e+12, 7.70755115e+12,
#        7.70647103e+12, 7.70632367e+12, 7.70595922e+12, 7.70619583e+12,
#        7.70642724e+12, 7.70574797e+12, 3.53114269e+13, 3.53110120e+13,
#        3.53110081e+13, 3.53117922e+13, 3.53117191e+13, 3.53114011e+13,
#        3.53111109e+13, 3.53112216e+13, 3.53107531e+13, 3.53094155e+13,
#        4.00127389e+13, 4.00125888e+13, 4.00124419e+13, 4.00121351e+13,
#        4.00127348e+13, 4.00126082e+13, 4.00128220e+13, 4.00132515e+13,
#        4.00127605e+13, 4.00105816e+13, 5.73733028e+13, 5.73731646e+13,
#        5.73733325e+13, 5.73732569e+13, 5.73731301e+13, 5.73732163e+13,
#        5.73729722e+13, 5.73730229e+13, 5.73728535e+13, 5.73719120e+13,
#        3.26026206e+13, 3.26025576e+13, 3.26028343e+13, 3.26024227e+13,
#        3.26023925e+13, 3.26022963e+13, 3.26022680e+13, 3.26023005e+13,
#        3.26020236e+13, 3.26013607e+13, 1.71779016e+13, 1.71782460e+13,
#        1.71783517e+13, 1.71782571e+13, 1.71784255e+13, 1.71783831e+13,
#        1.71782129e+13, 1.71783615e+13, 1.71783030e+13, 1.71782691e+13,
#        3.55498856e+13, 3.55501835e+13, 3.55500824e+13, 3.55501829e+13,
#        3.55502641e+13, 3.55503709e+13, 3.55503125e+13, 3.55501455e+13,
#        3.55502570e+13, 3.55498481e+13, 1.10822124e+13, 1.10822037e+13,
#        1.10823198e+13, 1.10824397e+13, 1.10824199e+13, 1.10828172e+13,
#        1.10826758e+13, 1.10827224e+13, 1.10828559e+13, 1.10825610e+13,
#        1.76863290e+13, 1.76863985e+13, 1.76866500e+13, 1.76866069e+13,
#        1.76868005e+13, 1.76867443e+13, 1.76864759e+13, 1.76864807e+13,
#        1.76864465e+13, 1.76863983e+13, 7.86853538e+12, 7.86868743e+12,
#        7.86883408e+12, 7.86880822e+12, 7.86917887e+12, 7.86883674e+12,
#        7.86885098e+12, 7.86876132e+12, 7.86888797e+12, 7.86813069e+12,
#        5.17827738e+13, 5.17826840e+13, 5.17832064e+13, 5.17838135e+13,
#        5.17845444e+13, 5.17851219e+13, 5.17854722e+13, 5.17857454e+13,
#        5.17853071e+13, 5.17833097e+13, 1.21549730e+13, 1.21561272e+13,
#        1.21568466e+13, 1.21580767e+13, 1.21562824e+13, 1.21555529e+13,
#        1.21559341e+13, 1.21554040e+13, 1.21554482e+13, 1.21543954e+13,
#        1.12516947e+14, 1.12516435e+14, 1.12516785e+14, 1.12516426e+14,
#        1.12516432e+14, 1.12516812e+14, 1.12517333e+14, 1.12517554e+14,
#        1.12517423e+14, 1.12515056e+14, 6.03055178e+13, 6.03059680e+13,
#        6.03069244e+13, 6.03072909e+13, 6.03074685e+13, 6.03072347e+13,
#        6.03072170e+13, 6.03070403e+13, 6.03063711e+13, 6.03058466e+13,
#        6.73597739e+13, 6.73595372e+13, 6.73593649e+13, 6.73593926e+13,
#        6.73592980e+13, 6.73590079e+13, 6.73589288e+13, 6.73589168e+13,
#        6.73585589e+13, 6.73579226e+13, 2.26619562e+13, 2.26617009e+13,
#        2.26618875e+13, 2.26624581e+13, 2.26629394e+13, 2.26629051e+13,
#        2.26629791e+13, 2.26630090e+13, 2.26628430e+13, 2.26626164e+13,
#        2.42371100e+13, 2.42369794e+13, 2.42368042e+13, 2.42368156e+13,
#        2.42370469e+13, 2.42370940e+13, 2.42373207e+13, 2.42373148e+13,
#        2.42369706e+13, 2.42365176e+13, 7.43177620e+13, 7.43176404e+13,
#        7.43179085e+13, 7.43179473e+13, 7.43184575e+13, 7.43183468e+13,
#        7.43179203e+13, 7.43177077e+13, 7.43175501e+13, 7.43162426e+13,
#        6.03935037e+12, 6.03949664e+12, 6.03917957e+12, 6.03921502e+12,
#        6.03906677e+12, 6.03941459e+12, 6.03939754e+12, 6.03989184e+12,
#        6.03991260e+12, 6.03929383e+12, 2.98401744e+13, 2.98401820e+13,
#        2.98405771e+13, 2.98407492e+13, 2.98408806e+13, 2.98408214e+13,
#        2.98406995e+13, 2.98406796e+13, 2.98403103e+13, 2.98396812e+13,
#        3.97767214e+13, 3.97768790e+13, 3.97779157e+13, 3.97782259e+13,
#        3.97781966e+13, 3.97781739e+13, 3.97782020e+13, 3.97779038e+13,
#        3.97777307e+13, 3.97770776e+13, 1.68439383e+14, 1.68438966e+14,
#        1.68439005e+14, 1.68439292e+14, 1.68439774e+14, 1.68439774e+14,
#        1.68439885e+14, 1.68440047e+14, 1.68439396e+14, 1.68438061e+14,
#        1.84464270e+13, 1.84461845e+13, 1.84466258e+13, 1.84462667e+13,
#        1.84462320e+13, 1.84459090e+13, 1.84462490e+13, 1.84457554e+13,
#        1.84453991e+13, 1.84450479e+13, 3.68664553e+12, 3.68665646e+12,
#        3.68743506e+12, 3.68777705e+12, 3.68782051e+12, 3.68797618e+12,
#        3.68743103e+12, 3.68745321e+12, 3.68779585e+12, 3.68711519e+12,
#        4.96199716e+13, 4.96195775e+13, 4.96202230e+13, 4.96209549e+13,
#        4.96210059e+13, 4.96208921e+13, 4.96207276e+13, 4.96208007e+13,
#        4.96203364e+13, 4.96189584e+13, 4.45708836e+13, 4.45702605e+13,
#        4.45705743e+13, 4.45705367e+13, 4.45704416e+13, 4.45704678e+13,
#        4.45711944e+13, 4.45713160e+13, 4.45709689e+13, 4.45692596e+13,
#        1.03367485e+13, 1.03365789e+13, 1.03367922e+13, 1.03365251e+13,
#        1.03365977e+13, 1.03366621e+13, 1.03365845e+13, 1.03362965e+13,
#        1.03366438e+13, 1.03361116e+13, 3.36724617e+13, 3.36726338e+13,
#        3.36725053e+13, 3.36724208e+13, 3.36724771e+13, 3.36723410e+13,
#        3.36722844e+13, 3.36722260e+13, 3.36720025e+13, 3.36714474e+13])

# %%
region_df["popestimate2022"] = regr.predict(X).round(2)
region_df["% inc_pop"] = ( ( region_df["popestimate2022"] - region_df["popestimate2021"] ) / region_df["popestimate2021"] ) * 100
region_df["State_name"] = market_pop_data["state_name"]
region_df["year_data"] = market_pop_data["year_data"]
region_df = region_df.sort_values( by = ["% inc_pop"], ascending = False)
region_df
# Out:
# /Users/oyukaagi/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
#      median_sale_price  median_list_price   homes_sold  new_listings  \
# 64         728758.3333        543783.3333   112.250000    139.833333
# 65         748250.0000        550266.6667   124.333333    153.250000
# 62         680175.0000        480333.3333   103.250000    126.083333
# 63         725766.6667        519300.0000   104.916667    129.916667
# 67         817666.6667        594208.3333   121.083333    147.416667
# ..                 ...                ...          ...           ...
# 122        178200.0000        193058.3333  1508.083333   1638.250000
# 124        209525.0000        222083.3333  1947.333333   1913.666667
# 123        192816.6667        205500.0000  1755.416667   1799.750000
# 120        145100.0000        160075.0000  1302.083333   1333.916667
# 121        167675.0000        178625.0000  1470.000000   1605.083333
#
#        inventory  avg_sale_to_list  sold_above_list  popestimate2010  \
# 64    272.500000          0.992744         0.338503         605282.0
# 65    305.916667          0.995881         0.339561         605282.0
# 62    268.166667          0.990499         0.316420         605282.0
# 63    274.166667          0.993041         0.335810         605282.0
# 67    318.250000          0.997641         0.342509         605282.0
# ..           ...               ...              ...              ...
# 122  8710.000000          0.979453         0.174783        1570819.0
# 124  7176.750000          0.987005         0.228040        1570819.0
# 123  7972.250000          0.982545         0.198838        1570819.0
# 120  7171.916667          0.979153         0.217209        1570819.0
# 121  7701.916667          0.981541         0.209002        1570819.0
#
#      popestimate2011  popestimate2012  ...  popestimate2016  popestimate2017  \
# 64          620290.0         635737.0  ...         687576.0         697079.0
# 65          620290.0         635737.0  ...         687576.0         697079.0
# 62          620290.0         635737.0  ...         687576.0         697079.0
# 63          620290.0         635737.0  ...         687576.0         697079.0
# 67          620290.0         635737.0  ...         687576.0         697079.0
# ..               ...              ...  ...              ...              ...
# 122        1584272.0        1595910.0  ...        1684036.0        1719745.0
# 124        1584272.0        1595910.0  ...        1684036.0        1719745.0
# 123        1584272.0        1595910.0  ...        1684036.0        1719745.0
# 120        1584272.0        1595910.0  ...        1684036.0        1719745.0
# 121        1584272.0        1595910.0  ...        1684036.0        1719745.0
#
#      popestimate2018  popestimate2019  popestimate2020  popestimate2021  \
# 64          704147.0         708253.0         712816.0         670050.0
# 65          704147.0         708253.0         712816.0         670050.0
# 62          704147.0         708253.0         712816.0         670050.0
# 63          704147.0         708253.0         712816.0         670050.0
# 67          704147.0         708253.0         712816.0         670050.0
# ..               ...              ...              ...              ...
# 122        1752074.0        1789060.0        1826913.0        1900923.0
# 124        1752074.0        1789060.0        1826913.0        1900923.0
# 123        1752074.0        1789060.0        1826913.0        1900923.0
# 120        1752074.0        1789060.0        1826913.0        1900923.0
# 121        1752074.0        1789060.0        1826913.0        1900923.0
#
#      popestimate2022     % inc_pop            State_name  year_data
# 64      4.119946e+12  6.148713e+08  District of Columbia       2016
# 65      4.119158e+12  6.147537e+08  District of Columbia       2017
# 62      4.118536e+12  6.146608e+08  District of Columbia       2014
# 63      4.118390e+12  6.146391e+08  District of Columbia       2015
# 67      4.117839e+12  6.145568e+08  District of Columbia       2019
# ..               ...           ...                   ...        ...
# 122     1.037539e+13  5.458080e+08                 Idaho       2014
# 124     1.037537e+13  5.458068e+08                 Idaho       2016
# 123     1.037530e+13  5.458032e+08                 Idaho       2015
# 120     1.037510e+13  5.457925e+08                 Idaho       2012
# 121     1.037498e+13  5.457864e+08                 Idaho       2013
#
# [460 rows x 23 columns]

# %%
region_df = region_df.set_index(["State_name"])
region_df["% inc_pop"].plot()
# Out:
# <AxesSubplot:xlabel='State_name'>
