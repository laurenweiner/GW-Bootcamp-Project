# %%
import sqlalchemy
from sqlalchemy import create_engine, func, inspect
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Get the data from SQL

# %%
# FOR PostgreSQL connection : 
db_string = f"postgresql://postgres:XB0j1ma!17@housingdata.cng7z9pmjc4z.us-east-1.rds.amazonaws.com:5432/postgres"
engine = create_engine(db_string)
conn = engine.connect()
inspector = inspect(engine)

# %%
#get all the data from SQL using conn 
results = conn.execute("SELECT * FROM metro_market_tracker")

#find the column names
column_list = []
for row in inspector.get_columns('metro_market_tracker'):
    column_list.append(row["name"])
    
metro_market_tracker = pd.DataFrame(results, columns = column_list)
print(metro_market_tracker.shape)
metro_market_tracker.head(25)
# Out:
# (6355, 9)
#       state_name year_data  median_sale_price  median_list_price  homes_sold  \
# 0   Aberdeen, WA      2012      111437.083333      132641.666667   56.666667
# 1   Aberdeen, WA      2013      116672.916667      131854.166667   65.166667
# 2   Aberdeen, WA      2014      119054.125000      134310.000000   76.000000
# 3   Aberdeen, WA      2015      133762.500000      145335.416667   85.583333
# 4   Aberdeen, WA      2016      146423.416667      156662.500000  102.916667
# 5   Aberdeen, WA      2017      166808.333333      178712.458333  115.416667
# 6   Aberdeen, WA      2018      192362.041667      197629.166667  121.083333
# 7   Aberdeen, WA      2019      212977.083333      219287.416667  120.750000
# 8   Aberdeen, WA      2020      245881.250000      254868.750000  130.666667
# 9   Aberdeen, WA      2021      304912.500000      318550.000000  143.666667
# 10   Abilene, TX      2012       99922.361111      106482.638889   44.222222
# 11   Abilene, TX      2013      104951.500000      110673.333333   48.416667
# 12   Abilene, TX      2014      119603.041667      128719.444444   49.750000
# 13   Abilene, TX      2015      127123.611111      126922.541667   54.666667
# 14   Abilene, TX      2016      128423.861111      124543.055556   59.833333
# 15   Abilene, TX      2017      120848.402778      126684.583333   63.916667
# 16   Abilene, TX      2018      132361.805556      143919.750000   63.138889
# 17   Abilene, TX      2019      148331.805556      156409.680556   66.027778
# 18   Abilene, TX      2020      163007.722222      166629.833333   74.777778
# 19   Abilene, TX      2021      175140.430556      184383.333333   77.305556
# 20       Ada, OK      2012       20000.000000      117900.000000    3.000000
# 21       Ada, OK      2013       31509.600000       60879.166667    2.200000
# 22       Ada, OK      2014       92510.200000      105250.000000    1.200000
# 23       Ada, OK      2015      100331.727273      126975.000000   25.909091
# 24       Ada, OK      2016      124662.500000      134720.833333   26.666667
#
#     new_listings   inventory  avg_sale_to_list  sold_above_list
# 0     109.750000  639.000000          0.938620         0.106285
# 1     121.250000  632.750000          0.945727         0.119967
# 2     114.083333  579.833333          0.949212         0.136773
# 3     114.833333  488.833333          0.954965         0.128775
# 4     124.833333  439.083333          0.963780         0.164270
# 5     133.333333  380.833333          0.976039         0.202932
# 6     142.333333  359.083333          0.979065         0.215098
# 7     141.000000  332.500000          0.983950         0.256738
# 8     135.000000  213.583333          0.995592         0.331761
# 9     156.000000  176.583333          1.011155         0.427970
# 10     62.500000  225.472222          0.943095         0.071438
# 11     61.555556  196.888889          0.957981         0.110740
# 12     61.416667  189.666667          0.949440         0.079833
# 13     69.861111  194.083333          0.954613         0.106455
# 14     74.444444  221.805556          0.948596         0.088028
# 15     74.638889  211.388889          0.953765         0.107715
# 16     77.416667  216.083333          0.961813         0.122975
# 17     77.861111  218.000000          0.963488         0.140508
# 18     80.694444  183.527778          0.961961         0.124892
# 19     84.666667  118.888889          0.972516         0.228386
# 20      1.000000    1.000000          0.866667         0.000000
# 21      2.666667    4.000000          0.975237         0.400000
# 22      4.500000   10.400000          1.023184         0.600000
# 23     26.181818  100.181818          0.965164         0.148676
# 24     43.083333  143.250000          0.950720         0.063206

# %%
metro_market_tracker.dtypes
# Out:
# state_name              object
# year_data               object
# median_sale_price      float64
# median_list_price      float64
# homes_sold             float64
# new_listings           float64
# inventory              float64
# avg_sale_to_list       float64
# sold_above_list        float64
# sold_above_list_yoy    float64
# dtype: object

# %%
metro_market_tracker['sold_above_list_yoy'] = metro_market_tracker["sold_above_list"].pct_change()
metro_market_tracker
# if metro_market_tracker["year_data"] == "2012":
#     metro_market_tracker["sold_above_list_yoy"] = 
metro_market_tracker
# Out:
#           state_name year_data  median_sale_price  median_list_price  \
# 0       Aberdeen, WA      2012      111437.083333      132641.666667
# 1       Aberdeen, WA      2013      116672.916667      131854.166667
# 2       Aberdeen, WA      2014      119054.125000      134310.000000
# 3       Aberdeen, WA      2015      133762.500000      145335.416667
# 4       Aberdeen, WA      2016      146423.416667      156662.500000
# ...              ...       ...                ...                ...
# 6350  Zanesville, OH      2017      120478.571429      111037.500000
# 6351  Zanesville, OH      2018      121694.636364      113909.090909
# 6352  Zanesville, OH      2019      164260.250000      172574.125000
# 6353  Zanesville, OH      2020      144449.750000      139495.833333
# 6354  Zanesville, OH      2021      166619.458333      165191.541667
#
#       homes_sold  new_listings   inventory  avg_sale_to_list  sold_above_list  \
# 0      56.666667    109.750000  639.000000          0.938620         0.106285
# 1      65.166667    121.250000  632.750000          0.945727         0.119967
# 2      76.000000    114.083333  579.833333          0.949212         0.136773
# 3      85.583333    114.833333  488.833333          0.954965         0.128775
# 4     102.916667    124.833333  439.083333          0.963780         0.164270
# ...          ...           ...         ...               ...              ...
# 6350    1.285714      1.000000    3.714286          0.960067         0.000000
# 6351    2.818182      4.727273   15.090909          0.996618         0.339394
# 6352    4.333333      4.583333   17.333333          0.956476         0.144444
# 6353    6.916667     10.833333   29.166667          0.958739         0.200893
# 6354   61.166667     76.000000  126.083333          0.991286         0.375291
#
#       sold_above_list_yoy
# 0                     NaN
# 1                0.128734
# 2                0.140087
# 3               -0.058480
# 4                0.275640
# ...                   ...
# 6350            -1.000000
# 6351                  inf
# 6352            -0.574405
# 6353             0.390797
# 6354             0.868117
#
# [6355 rows x 10 columns]

# %% [markdown]
# ### Explotary analysis

# %%
metro_market_tracker.isna().sum()
# Out:
# state_name             0
# year_data              0
# median_sale_price      8
# median_list_price    287
# homes_sold             8
# new_listings         290
# inventory            160
# avg_sale_to_list      25
# sold_above_list       10
# dtype: int64

# %%
metro_market_tracker = metro_market_tracker.dropna()
metro_market_tracker = metro_market_tracker.drop_duplicates()
metro_market_tracker.shape
# Out:
# (5891, 10)

# %%
df_state = metro_market_tracker.groupby("state_name").mean()
k = df_state.head(500).sort_values("median_sale_price", ascending = False)
# k.loc[k["state_name"] == "Urban Honolulu, HI"]
k
# Out:
#                                     median_sale_price  median_list_price  \
# state_name
# Massachusetts nonmetropolitan area       2.106652e+06       2.081351e+06
# New York, NY                             9.863797e+05       5.982122e+05
# Fredericksburg, TX                       8.119396e+05       9.633199e+05
# Breckenridge, CO                         7.992543e+05       5.747548e+05
# Heber, UT                                7.658987e+05       6.927288e+05
# ...                                               ...                ...
# Clarksdale, MS                           5.805607e+04       8.468572e+04
# Columbus, MS                             4.818133e+04       1.383000e+05
# Greenville, MS                           4.629809e+04       4.994199e+04
# Guymon, OK                               4.592500e+04       4.000000e+04
# Greenwood, MS                            4.531742e+04       6.697700e+04
#
#                                     homes_sold  new_listings    inventory  \
# state_name
# Massachusetts nonmetropolitan area    3.954545      6.709091    37.288636
# New York, NY                        225.646645    291.141234  1067.225649
# Fredericksburg, TX                    2.197172      3.415693    15.537475
# Breckenridge, CO                     13.141667     18.400000    74.475000
# Heber, UT                            59.154167     79.350000   354.066667
# ...                                        ...           ...          ...
# Clarksdale, MS                        1.458333      1.798333     5.954643
# Columbus, MS                          1.486111      1.122222     3.486111
# Greenville, MS                        1.351905      1.593333     3.931905
# Guymon, OK                            1.000000      1.000000     1.000000
# Greenwood, MS                         1.138889      1.111111     2.766667
#
#                                     avg_sale_to_list  sold_above_list  \
# state_name
# Massachusetts nonmetropolitan area          0.939788         0.060837
# New York, NY                                0.976901         0.200433
# Fredericksburg, TX                          0.942092         0.098843
# Breckenridge, CO                            0.965566         0.096128
# Heber, UT                                   0.972156         0.156769
# ...                                              ...              ...
# Clarksdale, MS                              0.892562         0.180060
# Columbus, MS                                0.888099         0.097222
# Greenville, MS                              0.932399         0.269167
# Guymon, OK                                  0.985144         0.500000
# Greenwood, MS                               0.920007         0.148810
#
#                                     sold_above_list_yoy
# state_name
# Massachusetts nonmetropolitan area                  NaN
# New York, NY                                   0.081488
# Fredericksburg, TX                                  NaN
# Breckenridge, CO                               0.518381
# Heber, UT                                      0.064576
# ...                                                 ...
# Clarksdale, MS                                      NaN
# Columbus, MS                                        NaN
# Greenville, MS                                      inf
# Guymon, OK                                     1.198642
# Greenwood, MS                                       NaN
#
# [500 rows x 8 columns]

# %%
#check density 
metro_market_tracker.index.name = None
metro_market_tracker['sold_above_list'].plot().hist
# Out:
# <bound method Axes.hist of <AxesSubplot:>>

# %%
df = metro_market_tracker.drop(columns = ["state_name"])
df.head(13)
# Out:
#    year_data  median_sale_price  median_list_price  homes_sold  new_listings  \
# 0       2012      111437.083333      132641.666667   56.666667    109.750000
# 1       2013      116672.916667      131854.166667   65.166667    121.250000
# 2       2014      119054.125000      134310.000000   76.000000    114.083333
# 3       2015      133762.500000      145335.416667   85.583333    114.833333
# 4       2016      146423.416667      156662.500000  102.916667    124.833333
# 5       2017      166808.333333      178712.458333  115.416667    133.333333
# 6       2018      192362.041667      197629.166667  121.083333    142.333333
# 7       2019      212977.083333      219287.416667  120.750000    141.000000
# 8       2020      245881.250000      254868.750000  130.666667    135.000000
# 9       2021      304912.500000      318550.000000  143.666667    156.000000
# 10      2012       99922.361111      106482.638889   44.222222     62.500000
# 11      2013      104951.500000      110673.333333   48.416667     61.555556
# 12      2014      119603.041667      128719.444444   49.750000     61.416667
#
#      inventory  avg_sale_to_list  sold_above_list
# 0   639.000000          0.938620         0.106285
# 1   632.750000          0.945727         0.119967
# 2   579.833333          0.949212         0.136773
# 3   488.833333          0.954965         0.128775
# 4   439.083333          0.963780         0.164270
# 5   380.833333          0.976039         0.202932
# 6   359.083333          0.979065         0.215098
# 7   332.500000          0.983950         0.256738
# 8   213.583333          0.995592         0.331761
# 9   176.583333          1.011155         0.427970
# 10  225.472222          0.943095         0.071438
# 11  196.888889          0.957981         0.110740
# 12  189.666667          0.949440         0.079833

# %%
# split into target and variables
y =  np.array(df.median_sale_price) #target
X = df.drop(columns = "median_sale_price" )

# %%
from sklearn.preprocessing import StandardScaler
data_scaler = StandardScaler()
X_scaled = data_scaler.fit_transform(X)
y_scaled = data_scaler.fit_transform(y.reshape(-1, 1))

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.25, random_state = 42)

# %%
# # Resample the training data with SMOTE
# from imblearn.over_sampling import SMOTE
# X_resampled, y_resampled = SMOTE(random_state=1, sampling_strategy='auto').fit_resample(
#     X_train, y_train
# )
# regr = LinearRegression()
# regr.fit(X_resampled, y_resampled)

# %%
regr = LinearRegression()
regr.fit(X_test, y_test)
# Out:
# LinearRegression()

# %%
pred = regr.predict(X_test)
pred_train = regr.predict(X_train)

# %%
from sklearn.metrics import mean_absolute_error, r2_score
print("MRE: " + str( mean_absolute_error(y_test, pred)))
print("R2: " + str(r2_score(y_test, pred)))
print("R2_train: " + str(r2_score(y_train, pred_train)))
print("R2 weighted: " + str(r2_score(y_test, pred, multioutput='variance_weighted')))
# Out:
# MRE: 0.057154123523575164
# R2: 0.5892371733577809
# R2_train: 0.5219242720718876
# R2 weighted: 0.5892371733577809

# %% [markdown]
# ## Classification

# %%
metro_market_tracker["sale_vs_list"] = metro_market_tracker['median_sale_price'] - metro_market_tracker['median_list_price']
metro_market_tracker
# Out:
#           state_name year_data  median_sale_price  median_list_price  \
# 1       Aberdeen, WA      2013      116672.916667      131854.166667
# 2       Aberdeen, WA      2014      119054.125000      134310.000000
# 3       Aberdeen, WA      2015      133762.500000      145335.416667
# 4       Aberdeen, WA      2016      146423.416667      156662.500000
# 5       Aberdeen, WA      2017      166808.333333      178712.458333
# ...              ...       ...                ...                ...
# 6350  Zanesville, OH      2017      120478.571429      111037.500000
# 6351  Zanesville, OH      2018      121694.636364      113909.090909
# 6352  Zanesville, OH      2019      164260.250000      172574.125000
# 6353  Zanesville, OH      2020      144449.750000      139495.833333
# 6354  Zanesville, OH      2021      166619.458333      165191.541667
#
#       homes_sold  new_listings   inventory  avg_sale_to_list  sold_above_list  \
# 1      65.166667    121.250000  632.750000          0.945727         0.119967
# 2      76.000000    114.083333  579.833333          0.949212         0.136773
# 3      85.583333    114.833333  488.833333          0.954965         0.128775
# 4     102.916667    124.833333  439.083333          0.963780         0.164270
# 5     115.416667    133.333333  380.833333          0.976039         0.202932
# ...          ...           ...         ...               ...              ...
# 6350    1.285714      1.000000    3.714286          0.960067         0.000000
# 6351    2.818182      4.727273   15.090909          0.996618         0.339394
# 6352    4.333333      4.583333   17.333333          0.956476         0.144444
# 6353    6.916667     10.833333   29.166667          0.958739         0.200893
# 6354   61.166667     76.000000  126.083333          0.991286         0.375291
#
#       sold_above_list_yoy  sale_vs_list
# 1                0.128734 -15181.250000
# 2                0.140087 -15255.875000
# 3               -0.058480 -11572.916667
# 4                0.275640 -10239.083333
# 5                0.235355 -11904.125000
# ...                   ...           ...
# 6350            -1.000000   9441.071429
# 6351                  inf   7785.545455
# 6352            -0.574405  -8313.875000
# 6353             0.390797   4953.916667
# 6354             0.868117   1427.916667
#
# [5891 rows x 11 columns]

# %%
positive_df = metro_market_tracker.loc[metro_market_tracker["sale_vs_list"] >= 0]
positive_names = positive_df["state_name"].value_counts()
positive_names_df = pd.DataFrame(positive_names)
big_cities = positive_names_df.loc[positive_names_df["state_name"] >=8]
big_cities["classification"] = 2
big_cities = big_cities.drop(columns = "state_name").reset_index()
big_cities = big_cities.rename(columns = {"index": "state_name"})
big_cities
# Out:
# /var/folders/bv/dwfzwz8x0l19lhv5ty4v0xxw0000gn/T/ipykernel_23871/1037803795.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   big_cities["classification"] = 2

# %%
big_cities_names = big_cities.index.tolist()
big_cities_names
# Out:
# ['Trenton, NJ',
#  'West Palm Beach, FL',
#  'Wilmington, DE',
#  'Camden, NJ',
#  'Las Vegas, NV',
#  'Lancaster, PA',
#  'California, MD',
#  'San Jose, CA',
#  'Seattle, WA',
#  'San Diego, CA',
#  'Harrisburg, PA',
#  'Buffalo, NY',
#  'Oakland, CA',
#  'Baltimore, MD',
#  'Urban Honolulu, HI',
#  'Philadelphia, PA',
#  'San Rafael, CA',
#  'Oxnard, CA',
#  'Lebanon, PA',
#  'San Francisco, CA',
#  'Myrtle Beach, SC',
#  'Georgetown, SC',
#  'Boulder, CO',
#  'York, PA',
#  'Reading, PA',
#  'Breckenridge, CO',
#  'Frederick, MD',
#  'Pottsville, PA',
#  'Montgomery County, PA',
#  'Allentown, PA',
#  'Manchester, NH',
#  'Port St. Lucie, FL',
#  'Anaheim, CA',
#  'Anchorage, AK',
#  'Ann Arbor, MI',
#  'Elgin, IL',
#  'Washington, DC',
#  'Fort Lauderdale, FL',
#  'Rockingham County, NH',
#  'Santa Cruz, CA',
#  'Chicago, IL',
#  'Champaign, IL',
#  'Naples, FL',
#  'Hartford, CT',
#  'Minneapolis, MN',
#  'Racine, WI',
#  'Fort Collins, CO',
#  'Milwaukee, WI',
#  'Amsterdam, NY',
#  'Heber, UT',
#  'Detroit, MI',
#  'Orlando, FL']

# %%
metro_market_tracker.groupby("state_name").mean().sort_values("median_sale_price", ascending = False)
# Out:
#                                     median_sale_price  median_list_price  \
# state_name
# Massachusetts nonmetropolitan area       2.106652e+06       2.081351e+06
# San Francisco, CA                        1.318918e+06       1.105632e+06
# San Rafael, CA                           1.169002e+06       1.040378e+06
# New York, NY                             9.863797e+05       5.982122e+05
# Vineyard Haven, MA                       8.613732e+05       1.013304e+06
# ...                                               ...                ...
# Clarksdale, MS                           5.805607e+04       8.468572e+04
# Columbus, MS                             4.818133e+04       1.383000e+05
# Greenville, MS                           4.629809e+04       4.994199e+04
# Guymon, OK                               4.592500e+04       4.000000e+04
# Greenwood, MS                            4.531742e+04       6.697700e+04
#
#                                     homes_sold  new_listings    inventory  \
# state_name
# Massachusetts nonmetropolitan area    3.954545      6.709091    37.288636
# San Francisco, CA                   287.187500    316.008333   375.920833
# San Rafael, CA                      184.750000    207.516667   344.800000
# New York, NY                        225.646645    291.141234  1067.225649
# Vineyard Haven, MA                   18.241667     23.558333   137.516667
# ...                                        ...           ...          ...
# Clarksdale, MS                        1.458333      1.798333     5.954643
# Columbus, MS                          1.486111      1.122222     3.486111
# Greenville, MS                        1.351905      1.593333     3.931905
# Guymon, OK                            1.000000      1.000000     1.000000
# Greenwood, MS                         1.138889      1.111111     2.766667
#
#                                     avg_sale_to_list  sold_above_list  \
# state_name
# Massachusetts nonmetropolitan area          0.939788         0.060837
# San Francisco, CA                           1.086206         0.699203
# San Rafael, CA                              1.015673         0.458028
# New York, NY                                0.976901         0.200433
# Vineyard Haven, MA                          0.944708         0.088747
# ...                                              ...              ...
# Clarksdale, MS                              0.892562         0.180060
# Columbus, MS                                0.888099         0.097222
# Greenville, MS                              0.932399         0.269167
# Guymon, OK                                  0.985144         0.500000
# Greenwood, MS                               0.920007         0.148810
#
#                                     sold_above_list_yoy   sale_vs_list  \
# state_name
# Massachusetts nonmetropolitan area                  NaN   25301.468939
# San Francisco, CA                              0.032383  213286.108333
# San Rafael, CA                                 0.054741  128623.954167
# New York, NY                                   0.081488  388167.449675
# Vineyard Haven, MA                             0.230435 -151930.733333
# ...                                                 ...            ...
# Clarksdale, MS                                      NaN  -26629.650536
# Columbus, MS                                        NaN  -90118.666667
# Greenville, MS                                      inf   -3643.897857
# Guymon, OK                                     1.198642    5925.000000
# Greenwood, MS                                       NaN  -21659.577381
#
#                                     classification
# state_name
# Massachusetts nonmetropolitan area             2.0
# San Francisco, CA                              2.0
# San Rafael, CA                                 2.0
# New York, NY                                   2.0
# Vineyard Haven, MA                             2.0
# ...                                            ...
# Clarksdale, MS                                 2.0
# Columbus, MS                                   2.0
# Greenville, MS                                 2.0
# Guymon, OK                                     2.0
# Greenwood, MS                                  2.0
#
# [666 rows x 10 columns]

# %%
merged_df = pd.merge(metro_market_tracker, big_cities, on = "state_name", how = 'left')
merged_df.head(5)
# Out:
#      state_name year_data  median_sale_price  median_list_price  homes_sold  \
# 0  Aberdeen, WA      2013      116672.916667      131854.166667   65.166667
# 1  Aberdeen, WA      2014      119054.125000      134310.000000   76.000000
# 2  Aberdeen, WA      2015      133762.500000      145335.416667   85.583333
# 3  Aberdeen, WA      2016      146423.416667      156662.500000  102.916667
# 4  Aberdeen, WA      2017      166808.333333      178712.458333  115.416667
#
#    new_listings   inventory  avg_sale_to_list  sold_above_list  \
# 0    121.250000  632.750000          0.945727         0.119967
# 1    114.083333  579.833333          0.949212         0.136773
# 2    114.833333  488.833333          0.954965         0.128775
# 3    124.833333  439.083333          0.963780         0.164270
# 4    133.333333  380.833333          0.976039         0.202932
#
#    sold_above_list_yoy  sale_vs_list  classification
# 0             0.128734 -15181.250000             NaN
# 1             0.140087 -15255.875000             NaN
# 2            -0.058480 -11572.916667             NaN
# 3             0.275640 -10239.083333             NaN
# 4             0.235355 -11904.125000             NaN

# %%
merged_df.mean()
# Out:
# /var/folders/bv/dwfzwz8x0l19lhv5ty4v0xxw0000gn/T/ipykernel_23871/1393354743.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   merged_df.mean()
# year_data                       inf
# median_sale_price      2.080242e+05
# median_list_price      2.207060e+05
# homes_sold             1.579869e+02
# new_listings           1.855046e+02
# inventory              5.480006e+02
# avg_sale_to_list       9.613340e-01
# sold_above_list        1.855392e-01
# sold_above_list_yoy             inf
# sale_vs_list          -1.268178e+04
# classification         2.000000e+00
# dtype: float64

# %%
national_avg_median_sale_price = 2.080242e+05
big_cities_df1 = merged_df.loc[merged_df['classification']== 2].groupby("state_name").mean().sort_values("median_sale_price", ascending = True)
big_cities_df1
# Out:
#                        median_sale_price  median_list_price   homes_sold  \
# state_name
# Amsterdam, NY               1.097399e+05       1.051705e+05    23.700000
# Pottsville, PA              1.102724e+05       8.286957e+04    68.591667
# Detroit, MI                 1.137549e+05       1.105410e+05  1605.005051
# Buffalo, NY                 1.385252e+05       1.330785e+05   392.133333
# Champaign, IL               1.605793e+05       1.534058e+05   148.931294
# Racine, WI                  1.637241e+05       1.587407e+05   184.491667
# Harrisburg, PA              1.837075e+05       1.717136e+05   138.041667
# York, PA                    1.890732e+05       1.722002e+05   376.466667
# Lebanon, PA                 1.919203e+05       1.707187e+05    98.591667
# Reading, PA                 1.931908e+05       1.632616e+05   284.166667
# Camden, NJ                  2.104540e+05       1.980739e+05   376.669949
# Wilmington, DE              2.113773e+05       2.016888e+05   172.661111
# Elgin, IL                   2.125121e+05       2.044447e+05   244.347222
# Allentown, PA               2.126560e+05       2.056007e+05   206.250000
# Myrtle Beach, SC            2.151410e+05       1.940922e+05   577.316667
# Lancaster, PA               2.271580e+05       2.004960e+05   312.050000
# Orlando, FL                 2.303780e+05       2.261699e+05   702.752083
# Chicago, IL                 2.362355e+05       2.277575e+05   931.743333
# Hartford, CT                2.432126e+05       2.385068e+05   327.483333
# Minneapolis, MN             2.456356e+05       2.409610e+05   246.398889
# Philadelphia, PA            2.510820e+05       1.966531e+05   284.083333
# Las Vegas, NV               2.526006e+05       2.451815e+05  2714.475000
# Milwaukee, WI               2.605585e+05       2.471148e+05   319.335938
# Ann Arbor, MI               2.607088e+05       2.531358e+05   326.958333
# Port St. Lucie, FL          2.615036e+05       2.435458e+05   351.200000
# Manchester, NH              2.829129e+05       2.677665e+05   349.241667
# Trenton, NJ                 2.906610e+05       2.480826e+05   241.875000
# Anchorage, AK               2.926282e+05       2.859609e+05   195.062500
# Rockingham County, NH       2.975618e+05       2.913068e+05   213.779167
# California, MD              3.007000e+05       2.891602e+05   111.283333
# Georgetown, SC              3.063284e+05       2.876055e+05    72.900000
# Fort Lauderdale, FL         3.306776e+05       2.566084e+05  1490.212963
# Baltimore, MD               3.334975e+05       2.972759e+05   250.779762
# West Palm Beach, FL         3.343961e+05       2.688975e+05  1405.475000
# Montgomery County, PA       3.404713e+05       3.178393e+05   487.161111
# Fort Collins, CO            3.560889e+05       3.472304e+05   473.708333
# Naples, FL                  4.112764e+05       3.751590e+05   531.055556
# Washington, DC              4.480041e+05       3.872570e+05   139.103623
# Frederick, MD               4.640922e+05       3.777660e+05   395.575000
# Seattle, WA                 5.034792e+05       4.680254e+05  1474.716667
# Boulder, CO                 5.179407e+05       4.753966e+05   319.108333
# San Diego, CA               5.817073e+05       5.404084e+05  1981.100000
# Oxnard, CA                  6.076312e+05       5.676567e+05   539.900000
# Oakland, CA                 6.933376e+05       6.162445e+05   895.516667
# Urban Honolulu, HI          7.554673e+05       5.590454e+05   292.441667
# Anaheim, CA                 7.563601e+05       6.738017e+05  1620.650000
# Heber, UT                   7.658987e+05       6.927288e+05    59.154167
# Breckenridge, CO            7.992543e+05       5.747548e+05    13.141667
# San Jose, CA                8.024914e+05       7.319998e+05   471.870833
# Santa Cruz, CA              8.026348e+05       7.600809e+05   158.475000
# San Rafael, CA              1.169002e+06       1.040378e+06   184.750000
# San Francisco, CA           1.318918e+06       1.105632e+06   287.187500
#
#                        new_listings    inventory  avg_sale_to_list  \
# state_name
# Amsterdam, NY             32.791667   151.291667          0.944075
# Pottsville, PA            89.275000   328.458333          0.960580
# Detroit, MI             2051.651515  4700.842593          0.972183
# Buffalo, NY              449.583333  1334.329167          0.980008
# Champaign, IL            182.383450   569.947835          0.965641
# Racine, WI               209.466667   728.700000          0.971039
# Harrisburg, PA           162.080556   549.288889          0.973926
# York, PA                 443.233333  1425.475000          0.978562
# Lebanon, PA              115.400000   415.700000          0.976095
# Reading, PA              338.100000  1064.216667          0.974809
# Camden, NJ               491.173990  1807.992424          0.971842
# Wilmington, DE           214.900000   684.347222          0.964436
# Elgin, IL                297.711111   822.005556          0.975628
# Allentown, PA            244.672222   786.905556          0.972444
# Myrtle Beach, SC         701.841667  3413.850000          0.974248
# Lancaster, PA            357.641667  1023.708333          0.979899
# Orlando, FL              828.225000  2314.589583          0.976536
# Chicago, IL             1201.265000  3440.158333          0.970820
# Hartford, CT             421.677778  1625.808333          0.973333
# Minneapolis, MN          279.693333   620.537222          0.988821
# Philadelphia, PA         355.366667  1178.412500          0.969636
# Las Vegas, NV           3120.758333  9301.191667          0.990966
# Milwaukee, WI            345.859375  1048.002604          0.983200
# Ann Arbor, MI            379.125000  1014.383333          0.984778
# Port St. Lucie, FL       400.379167  1388.879167          0.964823
# Manchester, NH           389.808333  1130.783333          0.991270
# Trenton, NJ              316.741667  1168.850000          0.968623
# Anchorage, AK            244.995833   884.287500          0.988507
# Rockingham County, NH    242.658333   777.658333          0.986019
# California, MD           143.208333   451.758333          0.982543
# Georgetown, SC            97.725000   579.125000          0.953574
# Fort Lauderdale, FL     1835.629630  5577.221380          0.969350
# Baltimore, MD            309.978571   866.480952          0.982496
# West Palm Beach, FL     1728.200000  6366.158333          0.960116
# Montgomery County, PA    598.688889  1835.002778          0.977094
# Fort Collins, CO         523.008333  1373.000000          0.994794
# Naples, FL               621.226852  2572.125000          0.961212
# Washington, DC           168.181653   392.691304          0.984916
# Frederick, MD            471.700000  1029.275000          0.990458
# Seattle, WA             1611.112500  2203.820833          1.011402
# Boulder, CO              356.891667   765.608333          0.993437
# San Diego, CA           2268.708333  4295.425000          0.987054
# Oxnard, CA               593.791667  1258.583333          0.989810
# Oakland, CA             1008.350000  1145.933333          1.042316
# Urban Honolulu, HI       344.475000  1176.925000          0.989436
# Anaheim, CA             1881.283333  4219.141667          0.987806
# Heber, UT                 79.350000   354.066667          0.972156
# Breckenridge, CO          18.400000    74.475000          0.965566
# San Jose, CA             518.045833   645.704167          1.018072
# Santa Cruz, CA           181.216667   404.883333          0.998756
# San Rafael, CA           207.516667   344.800000          1.015673
# San Francisco, CA        316.008333   375.920833          1.086206
#
#                        sold_above_list  sold_above_list_yoy   sale_vs_list  \
# state_name
# Amsterdam, NY                 0.201074             0.120761    4569.462500
# Pottsville, PA                0.139938             0.398815   27402.820833
# Detroit, MI                   0.266631             0.068464    3213.936027
# Buffalo, NY                   0.314956             0.104177    5446.685417
# Champaign, IL                 0.141895             0.144644    7173.519439
# Racine, WI                    0.243208             0.095102    4983.425000
# Harrisburg, PA                0.202418             0.111281   11993.943056
# York, PA                      0.187754             0.091781   16872.933333
# Lebanon, PA                   0.172647             0.079234   21201.529167
# Reading, PA                   0.183483             0.076128   29929.204167
# Camden, NJ                    0.229160             0.222808   12380.139520
# Wilmington, DE                0.190476             0.077172    9688.562500
# Elgin, IL                     0.219655             0.090024    8067.444444
# Allentown, PA                 0.224116                  NaN    7055.320833
# Myrtle Beach, SC              0.131489             0.043608   21048.775000
# Lancaster, PA                 0.152065             0.081747   26661.970833
# Orlando, FL                   0.194553             0.067234    4208.082292
# Chicago, IL                   0.196250             0.066617    8477.990833
# Hartford, CT                  0.233291             0.133090    4705.784722
# Minneapolis, MN               0.310760             0.110646    4674.543889
# Philadelphia, PA              0.187423             0.162870   54428.845833
# Las Vegas, NV                 0.282921             0.283297    7419.029167
# Milwaukee, WI                 0.290292             0.172668   13443.682292
# Ann Arbor, MI                 0.283266             0.076839    7573.020833
# Port St. Lucie, FL            0.147245             0.109226   17957.770833
# Manchester, NH                0.403007             0.100810   15146.441667
# Trenton, NJ                   0.211952             0.165929   42578.354167
# Anchorage, AK                 0.231307             0.005363    6667.239583
# Rockingham County, NH         0.356911             0.078875    6255.050000
# California, MD                0.218322             0.039921   11539.729167
# Georgetown, SC                0.090741             0.083153   18722.916667
# Fort Lauderdale, FL           0.173330             0.125517   74069.166667
# Baltimore, MD                 0.221420             0.079541   36221.585714
# West Palm Beach, FL           0.134801             0.063101   65498.633333
# Montgomery County, PA         0.207387             0.109947   22631.986111
# Fort Collins, CO              0.275521             0.132330    8858.500000
# Naples, FL                    0.105073             0.149330   36117.391204
# Washington, DC                0.251793             0.071412   60747.135194
# Frederick, MD                 0.262851             0.097345   86326.185417
# Seattle, WA                   0.416928             0.152624   35453.785417
# Boulder, CO                   0.293441             0.128665   42544.137500
# San Diego, CA                 0.296539             0.087959   41298.970833
# Oxnard, CA                    0.301741             0.172312   39974.579167
# Oakland, CA                   0.621436             0.051011   77093.150000
# Urban Honolulu, HI            0.295598             0.127867  196421.879167
# Anaheim, CA                   0.284166             0.088380   82558.416667
# Heber, UT                     0.156769             0.064576   73169.993750
# Breckenridge, CO              0.096128             0.518381  224499.520833
# San Jose, CA                  0.508660             0.038059   70491.581250
# Santa Cruz, CA                0.370937             0.070768   42553.854167
# San Rafael, CA                0.458028             0.054741  128623.954167
# San Francisco, CA             0.699203             0.032383  213286.108333
#
#                        classification
# state_name
# Amsterdam, NY                     2.0
# Pottsville, PA                    2.0
# Detroit, MI                       2.0
# Buffalo, NY                       2.0
# Champaign, IL                     2.0
# Racine, WI                        2.0
# Harrisburg, PA                    2.0
# York, PA                          2.0
# Lebanon, PA                       2.0
# Reading, PA                       2.0
# Camden, NJ                        2.0
# Wilmington, DE                    2.0
# Elgin, IL                         2.0
# Allentown, PA                     2.0
# Myrtle Beach, SC                  2.0
# Lancaster, PA                     2.0
# Orlando, FL                       2.0
# Chicago, IL                       2.0
# Hartford, CT                      2.0
# Minneapolis, MN                   2.0
# Philadelphia, PA                  2.0
# Las Vegas, NV                     2.0
# Milwaukee, WI                     2.0
# Ann Arbor, MI                     2.0
# Port St. Lucie, FL                2.0
# Manchester, NH                    2.0
# Trenton, NJ                       2.0
# Anchorage, AK                     2.0
# Rockingham County, NH             2.0
# California, MD                    2.0
# Georgetown, SC                    2.0
# Fort Lauderdale, FL               2.0
# Baltimore, MD                     2.0
# West Palm Beach, FL               2.0
# Montgomery County, PA             2.0
# Fort Collins, CO                  2.0
# Naples, FL                        2.0
# Washington, DC                    2.0
# Frederick, MD                     2.0
# Seattle, WA                       2.0
# Boulder, CO                       2.0
# San Diego, CA                     2.0
# Oxnard, CA                        2.0
# Oakland, CA                       2.0
# Urban Honolulu, HI                2.0
# Anaheim, CA                       2.0
# Heber, UT                         2.0
# Breckenridge, CO                  2.0
# San Jose, CA                      2.0
# Santa Cruz, CA                    2.0
# San Rafael, CA                    2.0
# San Francisco, CA                 2.0

# %%
# big_cities_df1.mean()
big_cities_df1.loc[big_cities_df1["median_sale_price"] <=national_avg_median_sale_price]
# Out:
#                 median_sale_price  median_list_price   homes_sold  \
# state_name
# Amsterdam, NY       109739.916667      105170.454167    23.700000
# Pottsville, PA      110272.395833       82869.575000    68.591667
# Detroit, MI         113754.926347      110540.990320  1605.005051
# Buffalo, NY         138525.235417      133078.550000   392.133333
# Champaign, IL       160579.309066      153405.789627   148.931294
# Racine, WI          163724.120833      158740.695833   184.491667
# Harrisburg, PA      183707.538889      171713.595833   138.041667
# York, PA            189073.183333      172200.250000   376.466667
# Lebanon, PA         191920.258333      170718.729167    98.591667
# Reading, PA         193190.812500      163261.608333   284.166667
#
#                 new_listings    inventory  avg_sale_to_list  sold_above_list  \
# state_name
# Amsterdam, NY      32.791667   151.291667          0.944075         0.201074
# Pottsville, PA     89.275000   328.458333          0.960580         0.139938
# Detroit, MI      2051.651515  4700.842593          0.972183         0.266631
# Buffalo, NY       449.583333  1334.329167          0.980008         0.314956
# Champaign, IL     182.383450   569.947835          0.965641         0.141895
# Racine, WI        209.466667   728.700000          0.971039         0.243208
# Harrisburg, PA    162.080556   549.288889          0.973926         0.202418
# York, PA          443.233333  1425.475000          0.978562         0.187754
# Lebanon, PA       115.400000   415.700000          0.976095         0.172647
# Reading, PA       338.100000  1064.216667          0.974809         0.183483
#
#                 sold_above_list_yoy  sale_vs_list  classification
# state_name
# Amsterdam, NY              0.120761   4569.462500             2.0
# Pottsville, PA             0.398815  27402.820833             2.0
# Detroit, MI                0.068464   3213.936027             2.0
# Buffalo, NY                0.104177   5446.685417             2.0
# Champaign, IL              0.144644   7173.519439             2.0
# Racine, WI                 0.095102   4983.425000             2.0
# Harrisburg, PA             0.111281  11993.943056             2.0
# York, PA                   0.091781  16872.933333             2.0
# Lebanon, PA                0.079234  21201.529167             2.0
# Reading, PA                0.076128  29929.204167             2.0

# %%
merged_df.loc[merged_df["state_name"] == "Austin, TX"]
# Out:
#      state_name year_data  median_sale_price  median_list_price  homes_sold  \
# 408  Austin, TX      2012      172054.083333      185878.016667  370.600000
# 409  Austin, TX      2013      185633.150000      201054.200000  439.216667
# 410  Austin, TX      2014      204830.925000      217680.041667  440.733333
# 411  Austin, TX      2015      223303.333333      236467.058333  463.083333
# 412  Austin, TX      2016      241299.050000      256624.866667  477.950000
# 413  Austin, TX      2017      254744.125000      264806.833333  490.133333
# 414  Austin, TX      2018      266187.516667      278743.841667  506.866667
# 415  Austin, TX      2019      275724.008333      286343.308333  549.433333
# 416  Austin, TX      2020      302942.258333      310589.466667  596.116667
# 417  Austin, TX      2021      394553.783333      395417.250000  584.333333
#
#      new_listings    inventory  avg_sale_to_list  sold_above_list  \
# 408    458.500000  1245.233333          0.964096         0.130672
# 409    503.933333  1004.683333          0.971141         0.168410
# 410    519.616667  1035.850000          0.976085         0.186831
# 411    538.733333  1080.933333          0.978822         0.209378
# 412    554.300000  1165.133333          0.979156         0.201795
# 413    587.500000  1307.700000          0.978826         0.185551
# 414    593.850000  1350.350000          0.979141         0.184973
# 415    609.766667  1293.616667          0.980896         0.188416
# 416    607.650000   953.183333          0.988651         0.250291
# 417    644.600000   752.950000          1.035365         0.543025
#
#      sold_above_list_yoy  sale_vs_list  classification
# 408            -0.705404 -13823.933333             NaN
# 409             0.288796 -15421.050000             NaN
# 410             0.109383 -12849.116667             NaN
# 411             0.120680 -13163.725000             NaN
# 412            -0.036216 -15325.816667             NaN
# 413            -0.080501 -10062.708333             NaN
# 414            -0.003114 -12556.325000             NaN
# 415             0.018615 -10619.300000             NaN
# 416             0.328393  -7647.208333             NaN
# 417             1.169580   -863.466667             NaN

# %%
merged_df.loc[merged_df["state_name"] == "Austin, TX"].plot()
# Out:
# <AxesSubplot:>
