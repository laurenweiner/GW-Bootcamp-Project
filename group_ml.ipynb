# %%
import pandas as pd

# %%
df = pd.read_csv("sfh_columns.csv")
df.columns
# Out:
# Index(['period_begin', 'period_end', 'table_id', 'region', 'state_code',
#        'median_sale_price', 'median_sale_price_mom', 'median_sale_price_yoy',
#        'median_list_price', 'median_list_price_mom', 'median_list_price_yoy',
#        'median_ppsf', 'median_ppsf_mom', 'median_ppsf_yoy', 'median_list_ppsf',
#        'median_list_ppsf_mom', 'median_list_ppsf_yoy', 'homes_sold',
#        'homes_sold_mom', 'homes_sold_yoy', 'pending_sales',
#        'pending_sales_mom', 'pending_sales_yoy', 'new_listings',
#        'new_listings_mom', 'new_listings_yoy', 'inventory', 'inventory_mom',
#        'inventory_yoy', 'months_of_supply', 'months_of_supply_mom',
#        'months_of_supply_yoy', 'median_dom', 'median_dom_mom',
#        'median_dom_yoy', 'avg_sale_to_list', 'avg_sale_to_list_mom',
#        'avg_sale_to_list_yoy', 'sold_above_list', 'sold_above_list_mom',
#        'sold_above_list_yoy'],
#       dtype='object')

# %%
df.head(3)
# Out:
#   period_begin period_end  table_id               region state_code  \
# 0       5/1/19    5/31/19      1586      Tate County, MS         MS
# 1       6/1/17    6/30/17      3227  Walworth County, WI         WI
# 2       6/1/18    6/30/18      2736  Hamilton County, TX         TX
#
#    median_sale_price  median_sale_price_mom  median_sale_price_yoy  \
# 0           165000.0              -0.144635              -0.046243
# 1           215500.0               0.051220               0.152406
# 2           153000.0               0.285714               0.602094
#
#    median_list_price  median_list_price_mom  ...  months_of_supply_yoy  \
# 0           181444.0              -0.090278  ...                   0.1
# 1           214000.0              -0.022831  ...                  -1.0
# 2           155000.0              -0.049080  ...                   3.5
#
#    median_dom  median_dom_mom  median_dom_yoy  avg_sale_to_list  \
# 0       117.0            17.0           -36.0          0.981283
# ...

# %%
df1.head(4)
# Out:
#                       table_id  median_sale_price  median_sale_price_mom  \
# region
# Abbeville County, SC    2433.0      139259.905983               0.321143
# Ada County, ID           668.0      285104.375000               0.011761
# Adair County, IA         906.0       91115.625000               0.225322
# Adair County, OK        2248.0       87042.542735               0.303754
#
#                       median_sale_price_yoy  median_list_price  \
# region
# Abbeville County, SC               0.508787      162002.052174
# Ada County, ID                     0.137571      296422.825000
# Adair County, IA                   0.265487       99211.169643
# Adair County, OK                   0.293090      108643.529915
#
#                       median_list_price_mom  median_list_price_yoy  \
# region
# Abbeville County, SC               0.217589               0.297950
# Ada County, ID                     0.011349               0.127767
# ...

# %%
df1 = df.groupby("region").mean()

# %%
df1.median_sale_price.plot()
# Out:
# <AxesSubplot:xlabel='region'>

# %%
max_mp = df1.median_sale_price.max()

# %%
df1.loc[df1.median_sale_price == max_mp
# Out:
#                      table_id  median_sale_price  median_sale_price_mom  \
# region
# New York County, NY    1975.0       5.948550e+06                0.21939
#
#                      median_sale_price_yoy  median_list_price  \
# region
# New York County, NY               0.655711        1329722.225
#
#                      median_list_price_mom  median_list_price_yoy  \
# region
# New York County, NY               0.005645              -0.004481
#
#                      median_ppsf  median_ppsf_mom  median_ppsf_yoy  ...  \
# region                                                              ...
# New York County, NY  1541.101462         0.072257         0.103146  ...
#
#                      months_of_supply_yoy  median_dom  median_dom_mom  \
# region
# New York County, NY              0.472059      309.25       -1.544304
#
#                      median_dom_yoy  avg_sale_to_list  avg_sale_to_list_mom  \
# region
# ...

# %%
df2 = df1.drop("New York County, NY")
df2.loc[df2.median_sale_price == df2.median_sale_price.max()]
# Out:
#                   table_id  median_sale_price  median_sale_price_mom  \
# region
# Foard County, TX    2717.0          3000000.0                    NaN
#
#                   median_sale_price_yoy  median_list_price  \
# region
# Foard County, TX                    NaN          3200000.0
#
#                   median_list_price_mom  median_list_price_yoy  median_ppsf  \
# region
# Foard County, TX                    NaN                    NaN       1250.0
#
#                   median_ppsf_mom  median_ppsf_yoy  ...  months_of_supply_yoy  \
# region                                              ...
# Foard County, TX              NaN              NaN  ...                   NaN
#
#                   median_dom  median_dom_mom  median_dom_yoy  \
# region
# Foard County, TX         4.0             NaN             NaN
#
#                   avg_sale_to_list  avg_sale_to_list_mom  \
# region
# Foard County, TX            0.9375                   NaN
#
# ...

# %%
df2.homes_sold.sort_values()
# Out:
# region
# Obion County, TN             1.000000
# Unicoi County, TN            1.000000
# Clarke County, MS            1.000000
# Jefferson County, MS         1.000000
# Atkinson County, GA          1.000000
#                              ...
# Harris County, TX         3675.433333
# Los Angeles County, CA    4323.800000
# Maricopa County, AZ       5549.125000
# El Paso County, CO                NaN
# Teller County, CO                 NaN
# Name: homes_sold, Length: 1859, dtype: float64
